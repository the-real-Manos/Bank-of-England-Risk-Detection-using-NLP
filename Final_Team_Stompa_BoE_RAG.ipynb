# %% [markdown]
# ### Initial Setup

# %%
# !pip install -U -q \
    pymupdf \
    sentence-transformers \
    transformers \
    langchain \
    langchain-chroma \
    langchain-community \
    langchain-google-genai \
    faiss-cpu \
    google-generativeai \
    PyPDF2 \
    anthropic \
    langchain-anthropic \
    langchain-ollama \
    langchain_huggingface \
    gradio
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 3.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 70.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 75.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 74.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.3/31.3 MB 30.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 18.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.3/289.3 kB 22.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.3/54.3 MB 12.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.9/323.9 kB 22.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.3/19.3 MB 78.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 41.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 45.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 35.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 108.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.2/284.2 kB 25.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 89.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 11.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 118.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.8/65.8 kB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.7/55.7 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.5/118.5 kB 11.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.2/196.2 kB 18.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.9/104.9 kB 10.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.2/71.2 kB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 459.8/459.8 kB 36.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 113.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 453.1/453.1 kB 33.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 9.5 MB/s eta 0:00:00
#   Building wheel for pypika (pyproject.toml) ... done

# %%
# Standard library imports
import io
import json
import os
from typing import Dict, List
from collections import defaultdict
import re

# Third-party data processing
import numpy as np
import pandas as pd

# PDF processing
import PyPDF2

# Google Colab and Drive
from google.colab import auth, drive, userdata
from googleapiclient.discovery import build
from googleapiclient.http import MediaIoBaseDownload
import googleapiclient.http

# AI/ML libraries
from anthropic import Anthropic
import google.generativeai as genai
from sentence_transformers import SentenceTransformer
from transformers import pipeline

# LangChain components
from langchain.chains import RetrievalQA
from langchain.document_loaders import PyMuPDFLoader
from langchain.schema import Document
from langchain.schema import HumanMessage
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import FAISS
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_anthropic import ChatAnthropic
from langchain_community.llms import Ollama
from langchain_ollama import OllamaLLM
from langchain_huggingface import HuggingFaceEmbeddings

# Necessary for Gradio
import gradio as gr
from datetime import datetime
import threading
import time
import ast

# %% [markdown]
# ### Pre Processing and Initial Chunking

# %%
# Retrieve files from Team Stompa on Google Drive
auth.authenticate_user()
service = build('drive', 'v3')

# Provide IDs for each folder
Transcripts = "1y1-7h6JbgFJ5l4lGiz2kFNhhzeUTsaQ6"
Basel = "1mPeX4pbjqEfsZuIc5HpT6dA9s_u_DLnD"
Principles = "1_a8-Rqv0dONJj65Rr4JPmpYlGgsbquQP"
Topic_Modelled_Results = "1MMtFQAiKc_EuDK8Q3dgFouPQSrXWhhHb"

# Create Folder Groups for future use
all_dir = [Transcripts, Basel, Principles]
transcripts_dir = [Transcripts]
principles_dir = [Principles]
topic_modelled_dir = [Topic_Modelled_Results]

# Folder, File and PDF functions
def get_files_from_folder(folder_id):
    """Retrieve all files from a specific folder"""
    try:
        files = service.files().list(
            q=f"'{folder_id}' in parents",
            fields="files(id, name, mimeType)"
        ).execute()
        return files.get('files', [])
    except Exception as e:
        print(f"Error accessing folder {folder_id}: {e}")
        return []

def iterate_thru_multiple_folders(folder_ids):
    """Iterate through multiple folders and retrieve files"""
    all_files = []
    for folder_id in folder_ids:
        folder_files = get_files_from_folder(folder_id)
        all_files.extend(folder_files)
    return all_files

def load_pdf_docs(file_list, drive_service, temp_dir="/tmp"):
    all_docs = []
    errors = []

    print(f"Loading PDFs")

    for file_info in file_list:
        # Only process PDF files
        if file_info['mimeType'] == 'application/pdf':
            file_id = file_info['id']
            file_name = file_info['name']
            temp_file_path = None

            try:
                # Download file from Google Drive
                request = drive_service.files().get_media(fileId=file_id)
                temp_file_path = os.path.join(temp_dir, file_name)

                with io.FileIO(temp_file_path, 'wb') as temp_file:
                    downloader = MediaIoBaseDownload(temp_file, request)
                    done = False
                    while done is False:
                        status, done = downloader.next_chunk()

                # Check if file was downloaded and has content
                if not os.path.exists(temp_file_path):
                    errors.append(f"Failed to download {file_name}: File not created")
                    continue

                if os.path.getsize(temp_file_path) == 0:
                    errors.append(f"Skipped {file_name}: File is empty")
                    continue

                # Load the downloaded PDF
                loader = PyMuPDFLoader(temp_file_path)
                docs = loader.load()

                # Check if any documents were loaded
                if not docs:
                    errors.append(f"Warning: {file_name} loaded but contains no extractable content")
                else:
                    all_docs.extend(docs)
                    print(f"✓ Successfully loaded {file_name} ({len(docs)} pages)")

            except Exception as e:
                error_msg = f"Error processing {file_name}: {str(e)}"
                errors.append(error_msg)
                print(f"✗ {error_msg}")

            finally:
                # Clean up temporary file if it exists
                if temp_file_path and os.path.exists(temp_file_path):
                    try:
                        os.remove(temp_file_path)
                    except Exception as cleanup_error:
                        errors.append(f"Failed to clean up {temp_file_path}: {str(cleanup_error)}")

    # Summary
    print(f"\nProcessing complete:")
    print(f"  Successfully loaded: {len(all_docs)} total documents")
    print(f"  Errors encountered: {len(errors)}")
    print()

    if errors:
        print("\nErrors:")
        for error in errors:
            print(f"  - {error}")
    print()

    return all_docs

# Set up lists of files for further parsing later
transcript_files = iterate_thru_multiple_folders(transcripts_dir)
principle_files = iterate_thru_multiple_folders(principles_dir)
topic_modelled_files = iterate_thru_multiple_folders(topic_modelled_dir)

# %%
# Read all pdfs from the list of docs
# all_transcript_docs = load_pdf_docs(transcript_files, service)
principle_docs = load_pdf_docs(principle_files, service)
topic_modelled_docs = load_pdf_docs(topic_modelled_files, service)
# Out:
# Loading PDFs
# ✓ Successfully loaded principle_9.pdf (3 pages)
# ✓ Successfully loaded principle_8.pdf (2 pages)
# ✓ Successfully loaded principle_7.pdf (2 pages)
# ✓ Successfully loaded principle_6.pdf (1 pages)
# ✓ Successfully loaded principle_5.pdf (2 pages)
# ✓ Successfully loaded principle_4.pdf (1 pages)
# ✓ Successfully loaded principle_3.pdf (1 pages)
# ✓ Successfully loaded principle_29.pdf (3 pages)
# ✓ Successfully loaded principle_28.pdf (1 pages)
# ✓ Successfully loaded principle_27.pdf (2 pages)
# ✓ Successfully loaded principle_26.pdf (3 pages)
# ✓ Successfully loaded principle_25.pdf (4 pages)
# ✓ Successfully loaded principle_24.pdf (3 pages)
# ✓ Successfully loaded principle_23.pdf (2 pages)
# ✓ Successfully loaded principle_22.pdf (2 pages)
# ✓ Successfully loaded principle_21.pdf (2 pages)
# ✓ Successfully loaded principle_20.pdf (2 pages)
# ✓ Successfully loaded principle_2.pdf (2 pages)
# ✓ Successfully loaded principle_19.pdf (2 pages)
# ✓ Successfully loaded principle_18.pdf (4 pages)
# ✓ Successfully loaded principle_17.pdf (2 pages)
# ✓ Successfully loaded principle_16.pdf (3 pages)
# ✓ Successfully loaded principle_15.pdf (4 pages)
# ✓ Successfully loaded principle_14.pdf (3 pages)
# ✓ Successfully loaded principle_13.pdf (3 pages)
# ✓ Successfully loaded principle_12.pdf (2 pages)
# ✓ Successfully loaded principle_11.pdf (2 pages)
# ✓ Successfully loaded principle_10.pdf (2 pages)
# ✓ Successfully loaded principle_1.pdf (2 pages)
#
# Processing complete:
#   Successfully loaded: 67 total documents
#   Errors encountered: 0
#
#
# Loading PDFs
# ✓ Successfully loaded UBS Topic Modelling Results.pdf (24 pages)
# ✓ Successfully loaded JPMorgan Topic Modelling Results.pdf (24 pages)
# ✓ Successfully loaded Citi Bank Topic Modelling Results.pdf (24 pages)
# ✓ Successfully loaded Silicon Vallet Topic Modelling Results.pdf (24 pages)
#
# Processing complete:
#   Successfully loaded: 96 total documents
#   Errors encountered: 0

# %%
# Apply Basic Chunking
splitter = RecursiveCharacterTextSplitter(chunk_size=800, chunk_overlap=100)
chunked_principles = splitter.split_documents(principle_docs)
# chunked_transcripts = splitter.split_documents(all_transcript_docs)
chunked_topic_modelled = splitter.split_documents(topic_modelled_docs)

# %% [markdown]
# ### LLM Config

# %%
# Initialize various LLM models
claude = ChatAnthropic(
    model="claude-3-5-sonnet-20241022",
    anthropic_api_key=userdata.get('ANTHROPIC_API_KEY')
    )

gemini = ChatGoogleGenerativeAI(
    model="gemini-2.0-flash",
    google_api_key=userdata.get('GOOGLE_API_KEY'),
    temperature=0.7
)

ollama = OllamaLLM(
    model="phi4:latest",
    base_url="https://humble-ladybug-actually.ngrok-free.app/",
    temperature=0.7
)

# %%
# Use native LLM APIs to test connection and capability
def get_responses(question, model):

    print(f"Question: {question}\n")

    # Get responses from model
    if model == "claude":
        response = claude.invoke([HumanMessage(content=question)])
        print(f"Claude's Response:\n{response.content}\n")

    elif model == "gemini":
        response = gemini.invoke([HumanMessage(content=question)])
        print(f"Gemini's Response:\n{response.content}\n")

    elif model == "ollama":
        response = ollama.invoke(question)
        print(f"Ollama's Response:\n{response}\n")

    else:
        print("Invalid model. Choose from 'claude', 'gemini', or 'ollama'.")

    return response

# %%
# Create Prompt to ask the LLM to identify particular questions that may be asked
question_prompt = """
You are a financial risk specialist working with large banks such as JP Morgan and Citi. Your job is to come up with questions about the financial risk of the bank and any things that could concern central banks or regulators such as the Bank of England.
You will provide ten questions to the bank in the form of a list as shown below:
["How has the liquidity of the bank been assessed for the next twelve months?", "What is the outlook for cash generation?", ...]

Requirements:
- Your output must be a valid python list containing the questions that you have generated.
- The questions should consider specific financial risk of the banks in question as well as any changes in the regulatory environment.
"""

# %%
# Test prompt with claude
get_responses(question_prompt, "claude")
# Out:
# Question:
# You are a financial risk specialist working with large banks such as JP Morgan and Citi. Your job is to come up with questions about the financial risk of the bank and any things that could concern central banks or regulators such as the Bank of England.
# You will provide ten questions to the bank in the form of a list as shown below:
# ["How has the liquidity of the bank been assessed for the next twelve months?", "What is the outlook for cash generation?", ...]
#
# Requirements:
# - Your output must be a valid python list containing the questions that you have generated.
# - The questions should consider specific financial risk of the banks in question as well as any changes in the regulatory environment.
#
#
# Claude's Response:
# [
#     "How has the bank stress-tested its capital adequacy ratios against potential economic downturns in 2024-2025?",
#     "What measures are in place to manage exposure to commercial real estate given current market vulnerabilities?",
#     "How is the bank addressing potential risks from rising interest rates on its loan portfolio quality?",
#     "What is the bank's exposure to emerging market debt and how is this risk being mitigated?",
#     "How does the bank plan to comply with new Basel III endgame requirements while maintaining profitability?",
#     "What contingency plans are in place for potential cyber security breaches affecting critical payment systems?",
#     "How is the bank managing climate-related transition risks in its investment and lending portfolios?",
#     "What is the current level of exposure to non-performing loans and how is this being provisioned?",
#     "How is the bank preparing for upcoming ESG disclosure requirements and regulatory standards?",
#     "What measures are in place to monitor and manage counterparty risk in derivatives trading operations?"
# ]
# AIMessage(content='[\n    "How has the bank stress-tested its capital adequacy ratios against potential economic downturns in 2024-2025?",\n    "What measures are in place to manage exposure to commercial real estate given current market vulnerabilities?",\n    "How is the bank addressing potential risks from rising interest rates on its loan portfolio quality?",\n    "What is the bank\'s exposure to emerging market debt and how is this risk being mitigated?",\n    "How does the bank plan to comply with new Basel III endgame requirements while maintaining profitability?",\n    "What contingency plans are in place for potential cyber security breaches affecting critical payment systems?",\n    "How is the bank managing climate-related transition risks in its investment and lending portfolios?",\n    "What is the current level of exposure to non-performing loans and how is this being provisioned?",\n    "How is the bank preparing for upcoming ESG disclosure requirements and regulatory standards?",\n    "What measures are in place to monitor and manage counterparty risk in derivatives trading operations?"\n]', additional_kwargs={}, response_metadata={'id': 'msg_01XENb5AwzddW4RHSz49BJcp', 'model': 'claude-3-5-sonnet-20241022', 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'input_tokens': 156, 'output_tokens': 237, 'server_tool_use': None, 'service_tier': 'standard'}, 'model_name': 'claude-3-5-sonnet-20241022'}, id='run--b69bf1ba-83fb-460e-b4df-2f7c9ba901d2-0', usage_metadata={'input_tokens': 156, 'output_tokens': 237, 'total_tokens': 393, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}})

# %%
# Test prompt with Gemini
get_responses(question_prompt, "gemini")
# Out:
# Question:
# You are a financial risk specialist working with large banks such as JP Morgan and Citi. Your job is to come up with questions about the financial risk of the bank and any things that could concern central banks or regulators such as the Bank of England.
# You will provide ten questions to the bank in the form of a list as shown below:
# ["How has the liquidity of the bank been assessed for the next twelve months?", "What is the outlook for cash generation?", ...]
#
# Requirements:
# - Your output must be a valid python list containing the questions that you have generated.
# - The questions should consider specific financial risk of the banks in question as well as any changes in the regulatory environment.
#
#
# Gemini's Response:
# ```python
# [
# "How has the liquidity of the bank been assessed for the next twelve months, considering potential deposit outflows under stressed scenarios and the availability of contingent funding?",
# "What is the outlook for cash generation, factoring in anticipated changes in interest rates, loan growth, and potential economic slowdowns impacting asset quality?",
# "What are the bank's projections for credit losses across different loan portfolios (e.g., commercial real estate, consumer loans) under various macroeconomic scenarios, and how do these projections compare to historical performance and industry benchmarks?",
# "How is the bank managing its exposure to interest rate risk, particularly in light of recent and anticipated future interest rate hikes by central banks, and what is the potential impact on net interest margin and asset values?",
# "What is the bank's strategy for managing operational risk, including cybersecurity threats, fraud, and model risk, and how are these risks being mitigated through robust controls and governance frameworks?",
# "How is the bank's capital adequacy ratio (CAR) expected to evolve over the next three years, considering planned growth initiatives, regulatory changes (e.g., Basel IV implementation), and potential stress testing scenarios?",
# "What are the bank's plans for addressing climate-related financial risks, including both physical risks (e.g., impact of extreme weather events on loan portfolios) and transition risks (e.g., impact of policy changes on fossil fuel investments)?",
# "How is the bank monitoring and managing its exposure to geopolitical risks, including potential disruptions to global supply chains, trade wars, and sovereign debt crises, and what contingency plans are in place to mitigate these risks?",
# "What are the key assumptions underlying the bank's stress testing models, and how sensitive are the results to changes in these assumptions, particularly those related to macroeconomic variables and market conditions?",
# "How is the bank ensuring compliance with evolving regulatory requirements, including anti-money laundering (AML) regulations, know-your-customer (KYC) procedures, and sanctions compliance, and what investments are being made to strengthen these areas?"
# ]
# ```
# AIMessage(content='```python\n[\n"How has the liquidity of the bank been assessed for the next twelve months, considering potential deposit outflows under stressed scenarios and the availability of contingent funding?",\n"What is the outlook for cash generation, factoring in anticipated changes in interest rates, loan growth, and potential economic slowdowns impacting asset quality?",\n"What are the bank\'s projections for credit losses across different loan portfolios (e.g., commercial real estate, consumer loans) under various macroeconomic scenarios, and how do these projections compare to historical performance and industry benchmarks?",\n"How is the bank managing its exposure to interest rate risk, particularly in light of recent and anticipated future interest rate hikes by central banks, and what is the potential impact on net interest margin and asset values?",\n"What is the bank\'s strategy for managing operational risk, including cybersecurity threats, fraud, and model risk, and how are these risks being mitigated through robust controls and governance frameworks?",\n"How is the bank\'s capital adequacy ratio (CAR) expected to evolve over the next three years, considering planned growth initiatives, regulatory changes (e.g., Basel IV implementation), and potential stress testing scenarios?",\n"What are the bank\'s plans for addressing climate-related financial risks, including both physical risks (e.g., impact of extreme weather events on loan portfolios) and transition risks (e.g., impact of policy changes on fossil fuel investments)?",\n"How is the bank monitoring and managing its exposure to geopolitical risks, including potential disruptions to global supply chains, trade wars, and sovereign debt crises, and what contingency plans are in place to mitigate these risks?",\n"What are the key assumptions underlying the bank\'s stress testing models, and how sensitive are the results to changes in these assumptions, particularly those related to macroeconomic variables and market conditions?",\n"How is the bank ensuring compliance with evolving regulatory requirements, including anti-money laundering (AML) regulations, know-your-customer (KYC) procedures, and sanctions compliance, and what investments are being made to strengthen these areas?"\n]\n```', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--647798e1-a94f-4186-854f-b048ace1767c-0', usage_metadata={'input_tokens': 142, 'output_tokens': 425, 'total_tokens': 567, 'input_token_details': {'cache_read': 0}})

# %%
# Non RAG LLM Query
get_responses("What is principle 9 of the BIS framework?", "claude")
# Out:
# Question: What is principle 9 of the BIS framework?
#
# Claude's Response:
# Principle 9 of the Basel Committee on Banking Supervision's Core Principles (BIS framework) deals with "Supervisory techniques and tools." This principle states that supervisors should use an appropriate range of techniques and tools to implement their supervisory approach and deploy supervisory resources on a proportionate basis, taking into account the risk profile and systemic importance of banks. It emphasizes the importance of having effective supervisory methodologies and both on-site and off-site supervision capabilities to assess banks' conditions, risks, internal control systems, and corrective measures when necessary.
# AIMessage(content='Principle 9 of the Basel Committee on Banking Supervision\'s Core Principles (BIS framework) deals with "Supervisory techniques and tools." This principle states that supervisors should use an appropriate range of techniques and tools to implement their supervisory approach and deploy supervisory resources on a proportionate basis, taking into account the risk profile and systemic importance of banks. It emphasizes the importance of having effective supervisory methodologies and both on-site and off-site supervision capabilities to assess banks\' conditions, risks, internal control systems, and corrective measures when necessary.', additional_kwargs={}, response_metadata={'id': 'msg_01E1CHJRK9qSmStBu69GGCww', 'model': 'claude-3-5-sonnet-20241022', 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'input_tokens': 19, 'output_tokens': 122, 'server_tool_use': None, 'service_tier': 'standard'}, 'model_name': 'claude-3-5-sonnet-20241022'}, id='run--ff7b3586-e2c8-46da-ad83-98786f5c2d73-0', usage_metadata={'input_tokens': 19, 'output_tokens': 122, 'total_tokens': 141, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}})

# %% [markdown]
# ### RAG Setup

# %%
# Basic RAG Setup

# Set the embedding function and initialise the vector store
embedding_function = HuggingFaceEmbeddings(model_name='all-mpnet-base-v2')
vectorstore = FAISS.from_documents(chunked_principles, embedding_function)

# Basic Retriever Settings
qa_chain = RetrievalQA.from_chain_type(
    llm=claude,
    retriever=vectorstore.as_retriever(),
    return_source_documents=True
)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
# Test the Basic RAG
query = "What is principle 9 of the BIS framework?"
result = qa_chain(query)

print("\nAnswer:\n", result["result"])
for doc in result["source_documents"]:
    print(f"\nSource: {doc.metadata['source']}")
    print(doc.page_content[:300], "...")
# Out:
# /tmp/ipython-input-13-313279715.py:3: LangChainDeprecationWarning: The method `Chain.__call__` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   result = qa_chain(query)
# Answer:
#  From the provided context, I cannot determine what Principle 9 of the BIS framework is. While the context includes information about several principles (including Principles 3, 12, 13, 27, and 29), it does not contain specific information about Principle 9. To accurately state what Principle 9 is, I would need context that directly addresses that principle.
#
# Source: /tmp/principle_3.pdf
# Principle 3 - Cooperation and collaboration
# 40.8 Principle 3: Laws, regulations or other arrangements provide a framework for
# cooperation and collaboration with relevant domestic authorities and foreign
# supervisors. These arrangements reflect the need to protect confidential information.6
# Footnotes  ...
#
# Source: /tmp/principle_26.pdf
# investments (including measures for the prevention and early detection and reporting of
# misuse, such as fraud, embezzlement, unauthorised trading and computer intrusion).
# More specifically, these controls address: (a) organisational structure: definitions of
# duties and responsibilities, including cl ...
#
# Source: /tmp/principle_10.pdf
# September 2012. 21 In the context of this principle, “prudential reports and statistical
# returns” are distinct from and required in addition to mandatory accounting reports.
# The former are addressed by this principle, and the latter are addressed in Principle 27
# BCP40.61.
# 40.24 Essential criteria: ( ...
#
# Source: /tmp/principle_18.pdf
# believe that all amounts due, including the principal and interest, may not be collected
# in accordance with the contractual terms of the agreement with the counterparty. 47
# Principle 18 covers all provisioning approaches (eg incurred loss models, expected credit
# loss models, calendar provisioning) t ...

# %% [markdown]
# ### RAG Tuning

# %%
# Combine principles back to one doc per principle

def combine_pages_to_principles(page_docs):
    # Group pages by their source (principle file)
    principle_groups = defaultdict(list)

    for doc in page_docs:
        # Use the source file path as the grouping key
        source = doc.metadata.get('source', 'unknown')
        principle_groups[source].append(doc)

    # Combine pages for each principle
    combined_principles = []

    for source, pages in principle_groups.items():
        # Sort pages by page number to ensure correct order
        pages.sort(key=lambda x: x.metadata.get('page', 0))

        # Combine all page content with double newlines for separation
        combined_content = '\n\n'.join([page.page_content for page in pages])

        # Create combined metadata from the first page
        combined_metadata = pages[0].metadata.copy()

        # Remove page-specific metadata and update with combined info
        combined_metadata.pop('page', None)  # Remove individual page number
        combined_metadata['combined_pages'] = len(pages)
        combined_metadata['page_range'] = f"0-{len(pages)-1}"

        # Extract principle name from source if possible
        if 'principle_' in source:
            principle_num = source.split('principle_')[1].split('.')[0]
            combined_metadata['principle_number'] = principle_num

        # Create the combined document
        combined_doc = Document(
            page_content=combined_content,
            metadata=combined_metadata
        )

        combined_principles.append(combined_doc)

    return combined_principles

# Sort by principle number for better organization
def extract_principle_number(doc):
    """Extract principle number for sorting"""
    principle_num = doc.metadata.get('principle_number')
    if principle_num:
        try:
            return int(principle_num)
        except ValueError:
            return float('inf')  # Put non-numeric at the end
    return float('inf')

# %%
# Update Principles Docs with the upgraded strategy
combined_principles = combine_pages_to_principles(principle_docs)
combined_principles.sort(key=extract_principle_number)

# %%
# Retrieve sizes of principle docs - really just for info
for doc in combined_principles:
    principle_num = doc.metadata.get('principle_number', 'Unknown')
    pages = doc.metadata.get('combined_pages', 0)
    length = len(doc.page_content)
    tokens = len(doc.page_content.split())
    print(f"Principle {principle_num}: {pages} pages, {length} characters, {tokens} tokens")
# Out:
# Principle 1: 2 pages, 3970 characters, 598 tokens
# Principle 2: 2 pages, 4913 characters, 719 tokens
# Principle 3: 1 pages, 2907 characters, 403 tokens
# Principle 4: 1 pages, 1442 characters, 224 tokens
# Principle 5: 2 pages, 5389 characters, 805 tokens
# Principle 6: 1 pages, 2384 characters, 353 tokens
# Principle 7: 2 pages, 2803 characters, 407 tokens
# Principle 8: 2 pages, 5187 characters, 726 tokens
# Principle 9: 3 pages, 6658 characters, 961 tokens
# Principle 10: 2 pages, 4483 characters, 638 tokens
# Principle 11: 2 pages, 4899 characters, 728 tokens
# Principle 12: 2 pages, 4223 characters, 611 tokens
# Principle 13: 3 pages, 5187 characters, 736 tokens
# Principle 14: 3 pages, 6222 characters, 891 tokens
# Principle 15: 4 pages, 12100 characters, 1751 tokens
# Principle 16: 3 pages, 6764 characters, 1014 tokens
# Principle 17: 2 pages, 6099 characters, 843 tokens
# Principle 18: 4 pages, 8544 characters, 1194 tokens
# Principle 19: 2 pages, 5443 characters, 770 tokens
# Principle 20: 2 pages, 5030 characters, 737 tokens
# Principle 21: 2 pages, 3761 characters, 541 tokens
# Principle 22: 2 pages, 3700 characters, 533 tokens
# Principle 23: 2 pages, 3401 characters, 498 tokens
# Principle 24: 3 pages, 7108 characters, 1006 tokens
# Principle 25: 4 pages, 12095 characters, 1679 tokens
# Principle 26: 3 pages, 5668 characters, 802 tokens
# Principle 27: 2 pages, 4220 characters, 605 tokens
# Principle 28: 1 pages, 3052 characters, 409 tokens
# Principle 29: 3 pages, 9216 characters, 1288 tokens

# %%
# Upgraded chunking strategy with greater markup and metadata
def create_principle_aware_chunks(principle_docs, chunk_size=500, chunk_overlap=50):
    # Custom separators for banking principles - hierarchical breakdown
    separators = [
        "\n\n# ",          # Major sections
        "\nPrinciple ",     # New principles
        "\nEssential criteria:", # Essential criteria sections
        "\nAdditional criterion:", # Additional criteria
        "\nFootnotes",      # Footnotes sections
        "\n\n",            # Paragraph breaks
        "\n",              # Line breaks
        ". ",              # Sentence endings
        " ",               # Word boundaries
        ""                 # Character level (last resort)
    ]

    # Configure the splitter
    text_splitter = RecursiveCharacterTextSplitter(
        separators=separators,
        chunk_size=chunk_size * 4,
        chunk_overlap=chunk_overlap,
        length_function=len,
        is_separator_regex=False,
    )

    all_chunks = []

    for doc in principle_docs:
        # Pre-process the document to identify key sections
        enhanced_content = enhance_content_structure(doc.page_content)

        # Create chunks
        chunks = text_splitter.split_text(enhanced_content)

        for i, chunk in enumerate(chunks):
            # Extract semantic context from the chunk
            chunk_metadata = doc.metadata.copy()
            chunk_metadata.update({
                'chunk_id': i,
                'total_chunks': len(chunks),
                'chunk_type': identify_chunk_type(chunk),
                'has_criteria': 'essential criteria' in chunk.lower() or 'additional criterion' in chunk.lower(),
                'has_footnotes': 'footnote' in chunk.lower(),
                'principle_section': extract_principle_section(chunk),
            })

            # Create Document object
            chunk_doc = Document(
                page_content=clean_chunk_content(chunk),
                metadata=chunk_metadata
            )
            all_chunks.append(chunk_doc)

    return all_chunks

def enhance_content_structure(content):
    """Add structure markers to help with semantic chunking."""

    # Add clear markers for different sections
    content = re.sub(r'(Essential criteria:)', r'\n\n### \1\n', content)
    content = re.sub(r'(Additional criterion:)', r'\n\n### \1\n', content)
    content = re.sub(r'(Footnotes?\s*\d*)', r'\n\n### \1\n', content)
    content = re.sub(r'\((\d+)\)', r'\n(\1)', content)  # Separate numbered criteria

    return content

def identify_chunk_type(chunk):
    """Identify the type of content in the chunk."""
    chunk_lower = chunk.lower()

    if 'principle' in chunk_lower and ':' in chunk:
        return 'principle_definition'
    elif 'essential criteria' in chunk_lower:
        return 'essential_criteria'
    elif 'additional criterion' in chunk_lower:
        return 'additional_criteria'
    elif 'footnote' in chunk_lower:
        return 'footnote'
    elif re.search(r'\(\d+\)', chunk):
        return 'numbered_criteria'
    else:
        return 'general_content'

def extract_principle_section(chunk):
    """Extract which specific section this chunk relates to."""

    # Look for numbered criteria
    criteria_match = re.search(r'\((\d+)\)', chunk)
    if criteria_match:
        return f"criteria_{criteria_match.group(1)}"

    # Look for specific topics
    if 'supervisory approach' in chunk.lower():
        return 'supervisory_approach'
    elif 'risk assessment' in chunk.lower():
        return 'risk_assessment'
    elif 'internal audit' in chunk.lower():
        return 'internal_audit'
    elif 'stress test' in chunk.lower():
        return 'stress_testing'

    return 'general'

def clean_chunk_content(chunk):
    """Clean up chunk content for better retrieval."""

    # Remove excessive whitespace
    chunk = re.sub(r'\n\s*\n\s*\n', '\n\n', chunk)
    chunk = re.sub(r'[ \t]+', ' ', chunk)

    # Ensure sentences are complete if possible
    chunk = chunk.strip()

    return chunk

# Add cross-references between chunks
def add_cross_references(chunks):
    """Add references to related chunks for better context."""

    principle_chunks = {}

    # Group chunks by principle
    for chunk in chunks:
        principle_num = chunk.metadata.get('principle_number', 'unknown')
        if principle_num not in principle_chunks:
            principle_chunks[principle_num] = []
        principle_chunks[principle_num].append(chunk)

    # Add cross-references
    for principle_num, principle_chunk_list in principle_chunks.items():
        for i, chunk in enumerate(principle_chunk_list):
            # Add references to adjacent chunks
            if i > 0:
                chunk.metadata['prev_chunk_id'] = principle_chunk_list[i-1].metadata['chunk_id']
            if i < len(principle_chunk_list) - 1:
                chunk.metadata['next_chunk_id'] = principle_chunk_list[i+1].metadata['chunk_id']

            chunk.metadata['related_chunks'] = len(principle_chunk_list)

    return chunks

# %%
# Re-chunk docs
re_chunked_docs = create_principle_aware_chunks(
    combined_principles,
    chunk_size=500,  # Adjust based on your needs
    chunk_overlap=50
)

# Apply cross-references
final_chunks = add_cross_references(re_chunked_docs)

print(f"Created {len(final_chunks)} chunks from {len(combined_principles)} principles")

# Analyze chunk distribution
chunk_types = {}
for chunk in final_chunks:
    chunk_type = chunk.metadata['chunk_type']
    chunk_types[chunk_type] = chunk_types.get(chunk_type, 0) + 1

print("Chunk type distribution:")
for chunk_type, count in chunk_types.items():
    print(f"  {chunk_type}: {count}")
# Out:
# Created 133 chunks from 29 principles
# Chunk type distribution:
#   principle_definition: 40
#   essential_criteria: 19
#   footnote: 18
#   numbered_criteria: 38
#   general_content: 16
#   additional_criteria: 2

# %%
# Save docs in case I want to pick up at this point
import pickle

# Save documents
with open('re_chunked_docs.pkl', 'wb') as f:
    pickle.dump(re_chunked_docs, f)

# %%
# # Load documents (optionally)
# with open('re_chunked_docs.pkl', 'rb') as f:
#     re_chunked_docs = pickle.load(f)

# %%
# Upgraded RAG Setup
embedding_function = HuggingFaceEmbeddings(model_name='all-mpnet-base-v2',
                                           encode_kwargs={'normalize_embeddings': True})
vectorstore2 = FAISS.from_documents(re_chunked_docs, embedding_function)

retriever = vectorstore2.as_retriever(
    search_type="mmr",  # Maximum Marginal Relevance for diversity
    search_kwargs={
        "k": 15,
        "fetch_k": 40,
        "lambda_mult": 0.5
    }
)

# Langchain flow
qa_chain = RetrievalQA.from_chain_type(
    llm=gemini,
    retriever=retriever,
    return_source_documents=True
)

# %%
# Test the Upgraded RAG
query = "What is principle 9 of the BIS framework?"
result = qa_chain(query)

print("\nAnswer:\n", result["result"])
for doc in result["source_documents"]:
    print(f"\nSource: {doc.metadata['source']}")
    print(doc.page_content[:300], "...")
# Out:
# Answer:
#  Principle 9 of the BIS framework is about Supervisory techniques and tools. The supervisor uses an appropriate range of techniques and tools to implement the supervisory approach and deploys supervisory resources on a proportionate basis, considering the risk profile and systemic importance of banks.
#
# Source: /tmp/principle_3.pdf
# Principle 3 - Cooperation and collaboration
# 40.8 Principle 3: Laws, regulations or other arrangements provide a framework for
# cooperation and collaboration with relevant domestic authorities and foreign
# supervisors. These arrangements reflect the need to protect confidential information.6
#
# ### Footn ...
#
# Source: /tmp/principle_9.pdf
# statements and accounts; (b) business model analysis; (c) horizontal peer reviews; (d)
# analysis of corporate governance, including risk management and internal control
# systems; (e) reviews of the outcome of stress tests undertaken by the banks; and (f)
# assessments of the adequacy of banks' capital a ...
#
# Source: /tmp/principle_11.pdf
# Principle 1, essential criterion 1 BCP40.5. ...
#
# Source: /tmp/principle_18.pdf
# Principle 18 covers all provisioning approaches (eg incurred loss models, expected credit
# loss models, calendar provisioning) that are used for prudential purposes. In some
# jurisdictions, cumulative provisions are referred to as loss allowances. 48 Reserves for
# the purposes of this principle are “be ...
#
# Source: /tmp/principle_9.pdf
# ### Footnotes
#  19
#  Refer to Principle 10 BCP40.23.
#
# 40.22
#
# ### Additional criterion:
#
# (1) The supervisor has a framework for periodic independent
# reviews, for example by an internal audit function, internal risk function or third-party
# assessor, of the adequacy and effectiveness of the range of it ...
#
# Source: /tmp/principle_29.pdf
# Principle 29 - Abuse of financial services
# 40.66 Principle 29:84 The supervisor determines that banks have adequate policies and
# processes, including robust and risk-based85 customer due diligence (CDD) rules and
# effective compliance functions to promote high ethical and professional standards in th ...
#
# Source: /tmp/principle_28.pdf
# Principle 28 - Disclosure and transparency
# 40.64 Principle 28:82 The supervisor determines that banks and banking groups
# regularly publish information on a consolidated and, where appropriate, solo basis that
# is easily accessible and fairly reflects their financial condition, performance, risk
# expos ...
#
# Source: /tmp/principle_25.pdf
# facilitate operational resilience in the event of an outage at a service provider, such as
# bringing the activity back in-house; (g) execution of comprehensive contracts and/or
# service level agreements that ensure a clear allocation of responsibilities between the
# service provider and the bank; and ( ...
#
# Source: /tmp/principle_15.pdf
# ### Footnotes 34
#  This
# includes, where relevant, risks not directly addressed in the subsequent principles, such
# as reputational, step-in and strategic risks. 35 Banks should include climate-related
# financial risks assessed as material over relevant time horizons, including in their stress
# testing p ...
#
# Source: /tmp/principle_5.pdf
# Principle 14 BCP40.32. 11 Refer to Principle 29 BCP40.66. ...
#
# Source: /tmp/principle_20.pdf
# Principle 20 - Transactions with related parties
# 40.46 Principle 20:55 To prevent abuses arising in transactions with related parties56
# and to address the risk of conflicts of interest, the supervisor requires banks to: enter
# into any transactions with related parties on an arm's length basis;57 mon ...
#
# Source: /tmp/principle_18.pdf
# ### Essential criteria:
#
# (1) Laws, regulations or the supervisor require banks to
# formulate policies, processes and methodologies for grading, classifying and monitoring
# all credit exposures (including off-balance sheet and forborne exposures49) and
# identifying and managing problem exposures. In ad ...
#
# Source: /tmp/principle_14.pdf
# ### Footnotes
# 28
#
# Independent director refers to a non-executive
# member of the board who does not
# have any management responsibilities within the
# bank and is not under any other
# undue influence, internal or external,
# political or ownership, that would impede the
#
# board member’s exercise of objective ...
#
# Source: /tmp/principle_25.pdf
# Principle 25 - Operational risk and operational resilience
# 40.56 Principle 25:68 The supervisor determines that banks have an adequate
# operational risk69 management framework and operational resilience70 approach that
# considers their risk profile, risk appetite, business environment, tolerance for d ...
#
# Source: /tmp/principle_9.pdf
# Principle 9 - Supervisory techniques and tools
# 40.20 Principle 9:18 The supervisor uses an appropriate range of techniques and tools to
# implement the supervisory approach and deploys supervisory resources on a
# proportionate basis, considering the risk profile and systemic importance of banks.
#
# ### F ...

# %% [markdown]
# ### Add Topic Modelled Results to the Vector Store

# %%
class ClaudePDFChunker:
    def __init__(self, api_key: str):
        self.client = Anthropic(api_key=api_key)

    def combine_pdf_pages(self, docs: List) -> str:
        combined_text = ""
        for doc in docs:
            if hasattr(doc, 'page_content'):
                combined_text += doc.page_content + "\n\n"
            elif hasattr(doc, 'content'):
                combined_text += doc.content + "\n\n"
            else:
                combined_text += str(doc) + "\n\n"
        return combined_text.strip()

    def group_docs_by_source(self, all_docs: List) -> Dict[str, List]:
        docs_by_source = {}

        for doc in all_docs:
            # Extract source filename from metadata
            source = "unknown"
            if hasattr(doc, 'metadata') and 'source' in doc.metadata:
                source = os.path.basename(doc.metadata['source'])
            elif hasattr(doc, 'metadata') and 'file_path' in doc.metadata:
                source = os.path.basename(doc.metadata['file_path'])

            if source not in docs_by_source:
                docs_by_source[source] = []
            docs_by_source[source].append(doc)

        return docs_by_source

    def split_into_sections(self, document_text: str) -> List[Dict]:
        chunks = []

        # Strategy 1: Look for common bank document patterns
        if "transcript" in document_text.lower() or "earnings" in document_text.lower():
            return self.split_earnings_transcript(document_text)
        elif "summary" in document_text.lower() and "risk" in document_text.lower():
            return self.split_risk_summary(document_text)
        else:
            return self.split_generic_document(document_text)

    def split_earnings_transcript(self, text: str) -> List[Dict]:
        chunks = []

        # Summary section
        summary_match = re.search(r'^(.*?)(?=Full results|--- Running|Transcript \d+)', text, re.DOTALL)
        if summary_match:
            chunks.append({
                'content': summary_match.group(1).strip(),
                'section_type': 'summary'
            })

        # Transcript sections
        transcript_sections = re.findall(
            r'(?:Transcript|Analyzing Transcript) (\d+).*?---(.*?)(?=(?:Transcript|Analyzing Transcript) \d+|\-{20,}|All Topics|$)',
            text, re.DOTALL
        )

        for transcript_num, content in transcript_sections:
            chunks.append({
                'content': content.strip(),
                'section_type': 'transcript_analysis',
                'transcript_num': transcript_num
            })

        # Consolidated section
        consolidated_match = re.search(r'(All Topics.*?)$', text, re.DOTALL)
        if consolidated_match:
            chunks.append({
                'content': consolidated_match.group(1).strip(),
                'section_type': 'consolidated'
            })

        return chunks

    def split_risk_summary(self, text: str) -> List[Dict]:
        chunks = []

        # Split by major headings
        sections = re.split(r'\n(?=#{1,3}\s+[A-Z])', text)

        for i, section in enumerate(sections):
            if section.strip():
                # Determine section type from heading
                section_type = "risk_section"
                if re.search(r'summary|overview', section[:100], re.IGNORECASE):
                    section_type = "summary"
                elif re.search(r'conclusion|recommendation', section[:100], re.IGNORECASE):
                    section_type = "conclusion"

                chunks.append({
                    'content': section.strip(),
                    'section_type': section_type,
                    'section_num': i + 1
                })

        return chunks

    def split_generic_document(self, text: str) -> List[Dict]:
        # Split by double line breaks or major headings
        sections = re.split(r'\n\s*\n\s*(?=[A-Z])', text)

        chunks = []
        for i, section in enumerate(sections):
            if len(section.strip()) > 100:  # Only include substantial sections
                chunks.append({
                    'content': section.strip(),
                    'section_type': 'section',
                    'section_num': i + 1
                })

        return chunks

    def get_analysis_prompt(self, chunk_content: str) -> str:
        return f"""
        Analyze this banking/financial document section and extract:

        1. Risk categories (credit, operational, liquidity, market, reputational, compliance)
        2. Key topics and themes
        3. Risk severity if mentioned
        4. Important metrics, ratios, or numbers
        5. Main concerns or issues
        6. Regulatory mentions

        Return as JSON:
        {{
            "risk_categories": ["category1", "category2"],
            "topics": ["topic1", "topic2"],
            "risk_level": "high/medium/low or null",
            "main_concerns": ["concern1", "concern2"],
            "metrics": ["metric1: value", "metric2: value"],
            "regulatory_mentions": ["regulation1", "regulation2"],
            "summary": "Brief summary of this section"
        }}

        Document section:
        {chunk_content[:3000]}
        """

    def analyze_chunk_with_claude(self, chunk: Dict, doc_name: str) -> Dict:
        prompt = self.get_analysis_prompt(chunk['content'])

        try:
            response = self.client.messages.create(
                model="claude-3-5-sonnet-20241022",
                max_tokens=1500,
                temperature=0,
                messages=[{"role": "user", "content": prompt}]
            )

            response_text = response.content[0].text
            json_match = re.search(r'\{.*\}', response_text, re.DOTALL)

            if json_match:
                metadata = json.loads(json_match.group())
                chunk['claude_analysis'] = metadata
            else:
                chunk['claude_analysis'] = {"error": "Could not parse JSON", "raw_response": response_text}

        except Exception as e:
            print(f"Claude analysis failed for chunk in {doc_name}: {e}")
            chunk['claude_analysis'] = {"error": str(e)}

        return chunk

    def process_single_document(self, document_text: str, doc_name: str, doc_id: str) -> List[Dict]:
        print(f"Processing document: {doc_name}")

        # Split into sections
        sections = self.split_into_sections(document_text)
        print(f"  Found {len(sections)} sections")

        # Create chunks with IDs
        chunks = []
        for i, section in enumerate(sections):
            chunk_id = f"{doc_id}_section_{i+1}"
            if 'transcript_num' in section:
                chunk_id = f"{doc_id}_transcript_{section['transcript_num']}"
            elif section['section_type'] == 'summary':
                chunk_id = f"{doc_id}_summary"
            elif section['section_type'] == 'consolidated':
                chunk_id = f"{doc_id}_consolidated"

            chunk = {
                'chunk_id': chunk_id,
                'doc_name': doc_name,
                'doc_id': doc_id,
                'content': section['content'],
                'section_type': section['section_type'],
                'char_count': len(section['content'])
            }

            # Add any additional metadata
            for key, value in section.items():
                if key not in ['content', 'section_type']:
                    chunk[key] = value

            chunks.append(chunk)

        # Analyze each chunk with Claude
        print(f"  Analyzing {len(chunks)} chunks with Claude...")
        for i, chunk in enumerate(chunks):
            print(f"    Chunk {i+1}/{len(chunks)}: {chunk['chunk_id']}")
            chunks[i] = self.analyze_chunk_with_claude(chunk, doc_name)

        return chunks

def process_all_documents(all_docs: List, api_key: str, output_dir: str = "chunked_outputs"):
    # Create output directory
    os.makedirs(output_dir, exist_ok=True)

    # Initialize chunker
    chunker = ClaudePDFChunker(api_key)

    # Group documents by source file
    docs_by_source = chunker.group_docs_by_source(all_docs)

    print(f"Found {len(docs_by_source)} unique documents to process")
    print("Documents found:")
    for source, pages in docs_by_source.items():
        print(f"  - {source}: {len(pages)} pages")
    print()

    all_chunks = []

    # Process each document
    for doc_name, doc_pages in docs_by_source.items():
        # Combine all pages into single text
        document_text = chunker.combine_pdf_pages(doc_pages)

        # Create document ID from filename
        doc_id = re.sub(r'[^a-zA-Z0-9_]', '_', doc_name.replace('.pdf', ''))

        # Process the document
        doc_chunks = chunker.process_single_document(document_text, doc_name, doc_id)

        # Save individual document chunks
        doc_output_file = os.path.join(output_dir, f"{doc_id}_chunks.json")
        with open(doc_output_file, 'w', encoding='utf-8') as f:
            json.dump(doc_chunks, f, indent=2, ensure_ascii=False)

        print(f"  ✓ Saved {len(doc_chunks)} chunks to {doc_output_file}")
        all_chunks.extend(doc_chunks)
        print()

    # Save all chunks together
    all_chunks_file = os.path.join(output_dir, "all_chunks_combined.json")
    with open(all_chunks_file, 'w', encoding='utf-8') as f:
        json.dump(all_chunks, f, indent=2, ensure_ascii=False)

    # Create summary
    summary = {
        "processing_date": datetime.now().isoformat(),
        "total_documents": len(docs_by_source),
        "total_chunks": len(all_chunks),
        "documents_processed": list(docs_by_source.keys()),
        "chunks_per_document": {doc_id: len([c for c in all_chunks if c['doc_id'] == doc_id])
                               for doc_id in set(c['doc_id'] for c in all_chunks)}
    }

    summary_file = os.path.join(output_dir, "processing_summary.json")
    with open(summary_file, 'w', encoding='utf-8') as f:
        json.dump(summary, f, indent=2, ensure_ascii=False)

    print(f"🎉 Processing complete!")
    print(f"  Total documents processed: {len(docs_by_source)}")
    print(f"  Total chunks created: {len(all_chunks)}")
    print(f"  Output directory: {output_dir}")
    print(f"  Combined chunks file: {all_chunks_file}")
    print(f"  Processing summary: {summary_file}")

    return all_chunks

# %%
topic_chunks = process_all_documents(topic_modelled_docs, userdata.get('ANTHROPIC_API_KEY'), "topic_modelled_chunks")
# Out:
# Found 4 unique documents to process
# Documents found:
#   - UBS Topic Modelling Results.pdf: 24 pages
#   - JPMorgan Topic Modelling Results.pdf: 24 pages
#   - Citi Bank Topic Modelling Results.pdf: 24 pages
#   - Silicon Vallet Topic Modelling Results.pdf: 24 pages
#
# Processing document: UBS Topic Modelling Results.pdf
#   Found 11 sections
#   Analyzing 11 chunks with Claude...
#     Chunk 1/11: UBS_Topic_Modelling_Results_summary
#     Chunk 2/11: UBS_Topic_Modelling_Results_transcript_1
#     Chunk 3/11: UBS_Topic_Modelling_Results_transcript_2
#     Chunk 4/11: UBS_Topic_Modelling_Results_transcript_3
#     Chunk 5/11: UBS_Topic_Modelling_Results_transcript_4
#     Chunk 6/11: UBS_Topic_Modelling_Results_transcript_5
#     Chunk 7/11: UBS_Topic_Modelling_Results_transcript_6
#     Chunk 8/11: UBS_Topic_Modelling_Results_transcript_7
#     Chunk 9/11: UBS_Topic_Modelling_Results_transcript_8
#     Chunk 10/11: UBS_Topic_Modelling_Results_transcript_9
#     Chunk 11/11: UBS_Topic_Modelling_Results_consolidated
#   ✓ Saved 11 chunks to topic_modelled_chunks/UBS_Topic_Modelling_Results_chunks.json
#
# Processing document: JPMorgan Topic Modelling Results.pdf
#   Found 11 sections
#   Analyzing 11 chunks with Claude...
#     Chunk 1/11: JPMorgan_Topic_Modelling_Results_summary
#     Chunk 2/11: JPMorgan_Topic_Modelling_Results_transcript_1
#     Chunk 3/11: JPMorgan_Topic_Modelling_Results_transcript_2
#     Chunk 4/11: JPMorgan_Topic_Modelling_Results_transcript_3
#     Chunk 5/11: JPMorgan_Topic_Modelling_Results_transcript_4
#     Chunk 6/11: JPMorgan_Topic_Modelling_Results_transcript_5
#     Chunk 7/11: JPMorgan_Topic_Modelling_Results_transcript_6
#     Chunk 8/11: JPMorgan_Topic_Modelling_Results_transcript_7
#     Chunk 9/11: JPMorgan_Topic_Modelling_Results_transcript_8
#     Chunk 10/11: JPMorgan_Topic_Modelling_Results_transcript_9
#     Chunk 11/11: JPMorgan_Topic_Modelling_Results_consolidated
#   ✓ Saved 11 chunks to topic_modelled_chunks/JPMorgan_Topic_Modelling_Results_chunks.json
#
# Processing document: Citi Bank Topic Modelling Results.pdf
#   Found 11 sections
#   Analyzing 11 chunks with Claude...
#     Chunk 1/11: Citi_Bank_Topic_Modelling_Results_summary
#     Chunk 2/11: Citi_Bank_Topic_Modelling_Results_transcript_1
#     Chunk 3/11: Citi_Bank_Topic_Modelling_Results_transcript_2
#     Chunk 4/11: Citi_Bank_Topic_Modelling_Results_transcript_3
#     Chunk 5/11: Citi_Bank_Topic_Modelling_Results_transcript_4
#     Chunk 6/11: Citi_Bank_Topic_Modelling_Results_transcript_5
#     Chunk 7/11: Citi_Bank_Topic_Modelling_Results_transcript_6
#     Chunk 8/11: Citi_Bank_Topic_Modelling_Results_transcript_7
#     Chunk 9/11: Citi_Bank_Topic_Modelling_Results_transcript_8
#     Chunk 10/11: Citi_Bank_Topic_Modelling_Results_transcript_9
#     Chunk 11/11: Citi_Bank_Topic_Modelling_Results_consolidated
#   ✓ Saved 11 chunks to topic_modelled_chunks/Citi_Bank_Topic_Modelling_Results_chunks.json
#
# Processing document: Silicon Vallet Topic Modelling Results.pdf
#   Found 11 sections
#   Analyzing 11 chunks with Claude...
#     Chunk 1/11: Silicon_Vallet_Topic_Modelling_Results_summary
#     Chunk 2/11: Silicon_Vallet_Topic_Modelling_Results_transcript_1
#     Chunk 3/11: Silicon_Vallet_Topic_Modelling_Results_transcript_2
#     Chunk 4/11: Silicon_Vallet_Topic_Modelling_Results_transcript_3
#     Chunk 5/11: Silicon_Vallet_Topic_Modelling_Results_transcript_4
#     Chunk 6/11: Silicon_Vallet_Topic_Modelling_Results_transcript_5
#     Chunk 7/11: Silicon_Vallet_Topic_Modelling_Results_transcript_6
#     Chunk 8/11: Silicon_Vallet_Topic_Modelling_Results_transcript_7
#     Chunk 9/11: Silicon_Vallet_Topic_Modelling_Results_transcript_8
#     Chunk 10/11: Silicon_Vallet_Topic_Modelling_Results_transcript_9
#     Chunk 11/11: Silicon_Vallet_Topic_Modelling_Results_consolidated
#   ✓ Saved 11 chunks to topic_modelled_chunks/Silicon_Vallet_Topic_Modelling_Results_chunks.json
#
# 🎉 Processing complete!
#   Total documents processed: 4
#   Total chunks created: 44
#   Output directory: topic_modelled_chunks
#   Combined chunks file: topic_modelled_chunks/all_chunks_combined.json
#   Processing summary: topic_modelled_chunks/processing_summary.json

# %%
for chunk in topic_chunks:
    print(chunk)
# Out:
# {'chunk_id': 'UBS_Topic_Modelling_Results_summary', 'doc_name': 'UBS Topic Modelling Results.pdf', 'doc_id': 'UBS_Topic_Modelling_Results', 'content': "Summary \n## Supervisory-Level Summary of Earnings Call Transcripts \n \n### Emerging Prudential Risks \n**Summary:** Over the past 2-3 years, the transcripts reveal significant concerns regarding \nemerging prudential risks, particularly in the context of regulatory scrutiny and operational \nresilience. The bank's exposure to low-interest-rate environments, particularly in the context \nof its net interest margin, has been a recurring theme. Additionally, the bank's operational \nrisk framework is under pressure due to increasing reliance on digital transformation and \npotential vulnerabilities in cybersecurity. \n \n**Topic Summaries:** \n1. **Low-Interest Rate Environment** \n   - **Keywords:** Interest rates, margin pressure, earnings impact \n   - **Risk Salience Score:** 4 \n   - **Supervisory Summary:** The bank faces ongoing challenges from a persistently \nlow-interest-rate environment, impacting net interest margins and overall profitability. This \ntrend could lead to increased credit risk as the bank seeks higher-yielding assets. \n   - **Confidence Level:** 0.85 \n \n2. **Operational Resilience and Cybersecurity** \n   - **Keywords:** Operational risk, cybersecurity, digital transformation \n   - **Risk Salience Score:** 5 \n   - **Supervisory Summary:** The bank's increasing reliance on digital platforms raises \noperational risks, particularly concerning cybersecurity threats. Enhanced scrutiny is \nnecessary to ensure adequate defenses are in place. \n   - **Confidence Level:** 0.90 \n \n3. **Regulatory Scrutiny** \n   - **Keywords:** Compliance, regulatory risk, scrutiny \n   - **Risk Salience Score:** 4 \n   - **Supervisory Summary:** The bank is experiencing heightened regulatory scrutiny, \nparticularly regarding its compliance frameworks. This could lead to reputational risks and \npotential penalties if not addressed. \n   - **Confidence Level:** 0.80 \n \n4. **Credit Risk in Commercial Real Estate** \n   - **Keywords:** Credit risk, commercial real estate, exposure \n   - **Risk Salience Score:** 4 \n   - **Supervisory Summary:** Analysts have raised concerns about the bank's exposure to \ncommercial real estate, particularly in light of potential downturns in the sector. This could \nheighten credit risk and necessitate closer monitoring. \n   - **Confidence Level:** 0.75 \n \n5. **Liquidity Risk Management**\n\n- **Keywords:** Liquidity risk, funding, market conditions \n   - **Risk Salience Score:** 3 \n   - **Supervisory Summary:** The bank's liquidity management strategies are under \nscrutiny, especially in volatile market conditions. Ensuring sufficient liquidity buffers is critical \nto maintaining operational stability. \n   - **Confidence Level:** 0.70 \n \n### Strategic Shifts \n**Summary:** The bank has indicated strategic shifts towards enhancing its digital \ncapabilities and diversifying its revenue streams. This includes a focus on emerging markets \nand a commitment to sustainability initiatives. However, these shifts also bring new risks, \nparticularly in operational and reputational domains. \n \n**Topic Summaries:** \n1. **Digital Transformation Initiatives** \n   - **Keywords:** Digital strategy, innovation, investment \n   - **Risk Salience Score:** 4 \n   - **Supervisory Summary:** The bank is investing heavily in digital transformation to \nenhance customer experience and operational efficiency. While this is strategically sound, it \nintroduces new operational risks that require careful management. \n   - **Confidence Level:** 0.85 \n \n2. **Focus on Sustainability** \n   - **Keywords:** Sustainability, ESG, investment strategy \n   - **Risk Salience Score:** 3 \n   - **Supervisory Summary:** The bank's commitment to sustainability and ESG principles is \nevident in its strategic direction. However, this may expose the bank to  ...
# {'chunk_id': 'UBS_Topic_Modelling_Results_transcript_1', 'doc_name': 'UBS Topic Modelling Results.pdf', 'doc_id': 'UBS_Topic_Modelling_Results', 'content': '--- GPT-4 Topic Modelling Output --- \nExcerpt for Analysis: \n \n"In response to your question about our recent decision to exit certain emerging markets, we \nbelieve this is a strategic move that will allow us to focus on our core markets where we \nhave a competitive advantage. We have seen a significant increase in regulatory scrutiny in \nthese markets, and we believe that the risk-reward balance is no longer favorable.  \n \nRegarding our loan book, we have been aggressively de-risking our portfolio, particularly in \nthe commercial real estate sector. We have seen a significant downturn in this sector, and \nwe believe that it is prudent to reduce our exposure at this time.  \n \nOn the topic of our IT infrastructure, we have been investing heavily in upgrading our \nsystems to improve efficiency and reduce operational risk. We have also been working to \nstrengthen our cyber security defenses in response to increasing threats.  \n \nAs for our liquidity position, we have been maintaining a strong liquidity buffer to ensure that \nwe can meet our obligations even in a stressed scenario. We have also been diversifying our \nfunding sources to reduce our reliance on wholesale funding.  \n \nFinally, on the topic of conduct risk, we have been implementing a comprehensive program \nto improve our culture and conduct. We have been investing in training and development to \nensure that our staff understand and adhere to our ethical standards." \n \nTopic Identification: \n \n1. Strategic exit from certain emerging markets \n2. De-risking of the loan book, particularly in the commercial real estate sector \n3. Investment in IT infrastructure and cyber security defenses \n4. Maintenance of a strong liquidity position and diversification of funding sources \n5. Implementation of a program to improve culture and conduct \n \nDetailed Topic Analysis: \n \nTopic Title: Strategic Exit from Emerging Markets \nKeywords: Emerging markets, strategic exit, regulatory scrutiny, risk-reward balance \nRisk Salience Score: 4 (The bank\'s exit from certain emerging markets due to increased \nregulatory scrutiny and unfavorable risk-reward balance could indicate a significant strategic \nshift and potential reputational risk.)\n\nSummary for Supervisor: The bank\'s decision to exit certain emerging markets due to \nincreased regulatory scrutiny could indicate a strategic shift and potential reputational risk. \nThis move could affect the bank\'s risk profile and market position. \nSource Citation: "In response to your question about our recent decision to exit certain \nemerging markets, we believe this is a strategic move that will allow us to focus on our core \nmarkets where we have a competitive advantage. We have seen a significant increase in \nregulatory scrutiny in these markets, and we believe that the risk-reward balance is no \nlonger favorable." \nConfidence Score: 0.9 \n \nTopic Title: De-risking of the Loan Book \nKeywords: Loan book, de-risking, commercial real estate, downturn, exposure \nRisk Salience Score: 4 (The bank\'s aggressive de-risking of its loan book, particularly in the \ncommercial real estate sector, could indicate credit risk concerns.) \nSummary for Supervisor: The bank\'s aggressive de-risking of its loan book, particularly in the \ncommercial real estate sector, could indicate credit risk concerns. This move could affect the \nbank\'s risk profile and profitability. \nSource Citation: "Regarding our loan book, we have been aggressively de-risking our \nportfolio, particularly in the commercial real estate sector. We have seen a significant \ndownturn in this sector, and we believe that it is prudent to reduce our exposure at this time." \nConfidence Score: 0.9 \n \nTopic Title: Investment in IT Infrastructure and Cyber Security \nKeywords: IT infrastruct ...
# {'chunk_id': 'UBS_Topic_Modelling_Results_transcript_2', 'doc_name': 'UBS Topic Modelling Results.pdf', 'doc_id': 'UBS_Topic_Modelling_Results', 'content': '--- GPT-4 Topic Modelling Output --- \nExcerpt for Analysis: \n \n"The bank\'s net interest margin (NIM) has been under pressure due to the low interest rate \nenvironment. Management is considering changes to the bank\'s business model to mitigate \nthis. They are looking at increasing their exposure to higher-yielding assets, including \ncorporate loans and emerging markets. The bank has also been facing increased \ncompetition in its core markets, which has been eroding its market share. In response, the \nbank is considering expanding into new markets and diversifying its product offerings. There \nhave been some concerns raised about the bank\'s IT systems, with several high-profile IT \nfailures in the past year. The bank is investing in upgrading its IT systems, but this will take \ntime and require significant capital expenditure. The bank\'s capital adequacy ratio (CAR) \nremains strong, but there are concerns about the potential impact of the proposed changes \nto the business model on the bank\'s capital position. Finally, there have been some concerns \nraised about the bank\'s exposure to the commercial real estate sector, given the current \neconomic climate." \n \nKey Topics: \n \n1. Pressure on Net Interest Margin (NIM) due to low interest rate environment \n2. Increased competition in core markets \n3. Concerns about IT systems and related failures \n4. Capital adequacy ratio (CAR) and potential impact of business model changes \n5. Exposure to the commercial real estate sector \n \nDetailed Topic Analysis: \n \nTopic Title: Pressure on Net Interest Margin \nKeywords: Net Interest Margin, low interest rate, business model change \nRisk Salience Score: 4 (The low interest rate environment and its impact on NIM is a \nsignificant financial risk.)\n\nSummary for Supervisor: The bank\'s NIM is under pressure due to the low interest rate \nenvironment, prompting potential changes to the business model, including increased \nexposure to higher-yielding assets. This could indicate a shift in risk appetite. \nSource Citation: "The bank\'s net interest margin (NIM) has been under pressure due to the \nlow interest rate environment. Management is considering changes to the bank\'s business \nmodel to mitigate this." \nConfidence Score: 0.9 \n \nTopic Title: Increased Competition in Core Markets \nKeywords: Competition, market share, diversification \nRisk Salience Score: 3 (Increased competition could lead to strategic shifts and potential \nreputational risk.) \nSummary for Supervisor: The bank is facing increased competition in its core markets, \neroding its market share. This may lead to strategic shifts, including market diversification, \nwhich could alter the bank\'s risk profile. \nSource Citation: "The bank has also been facing increased competition in its core markets, \nwhich has been eroding its market share." \nConfidence Score: 0.8 \n \nTopic Title: IT Systems Concerns \nKeywords: IT failures, operational risk, capital expenditure \nRisk Salience Score: 4 (IT failures pose a significant operational risk and could impact the \nbank\'s reputation.) \nSummary for Supervisor: The bank has experienced several high-profile IT failures, leading \nto significant planned capital expenditure for system upgrades. This represents a significant \noperational and potential reputational risk. \nSource Citation: "There have been some concerns raised about the bank\'s IT systems, with \nseveral high-profile IT failures in the past year." \nConfidence Score: 0.9 \n \nTopic Title: Capital Adequacy and Business Model Changes \nKeywords: Capital adequacy ratio, business model change, capital position \nRisk Salience Score: 4 (Changes to the business model could impact the bank\'s capital \nposition, posing a financial risk.) \nSummary for Supervisor: While the bank\'s CAR  ...
# {'chunk_id': 'UBS_Topic_Modelling_Results_transcript_3', 'doc_name': 'UBS Topic Modelling Results.pdf', 'doc_id': 'UBS_Topic_Modelling_Results', 'content': '--- GPT-4 Topic Modelling Output --- \nExcerpt for Analysis: \n \n"1. Our net interest margin (NIM) has been under pressure due to the low interest rate \nenvironment. We are considering various strategies to mitigate this, including repricing some \nof our loan products. \n \n2. We have seen an uptick in defaults in our auto loan portfolio, particularly in the subprime \nsegment. We are closely monitoring this situation and have increased our loan loss \nprovisions accordingly. \n \n3. We are in the process of implementing a new IT system to improve our operational \nefficiency. However, the project has been delayed due to some unforeseen technical issues. \n \n4. We have seen a significant increase in our deposit base, which has improved our liquidity \nposition. However, we are also seeing increased competition for deposits in the market. \n \n5. We are facing regulatory scrutiny over our sales practices, which could potentially lead to \nfines and reputational damage." \n \nTopic Identification: \n \n- Pressure on Net Interest Margin (NIM) \n- Increase in Auto Loan Defaults \n- Implementation of New IT System \n- Increase in Deposit Base and Competition \n- Regulatory Scrutiny Over Sales Practices \n \nDetailed Topic Analysis: \n \nTopic Title: Pressure on Net Interest Margin (NIM) \nKeywords: Net Interest Margin, low interest rate, loan products repricing \nRisk Salience Score: 3 (The low interest rate environment and its impact on NIM could affect \nthe bank\'s profitability.) \nSummary for Supervisor: The bank\'s NIM is under pressure due to the low interest rate \nenvironment, which could affect its profitability. They are considering repricing some loan \nproducts to mitigate this.\n\nSource Citation: "Our net interest margin (NIM) has been under pressure due to the low \ninterest rate environment. We are considering various strategies to mitigate this, including \nrepricing some of our loan products." \nConfidence Score: 0.9 \n \nTopic Title: Increase in Auto Loan Defaults \nKeywords: Auto loan, defaults, subprime segment, loan loss provisions \nRisk Salience Score: 4 (An uptick in defaults, especially in the subprime segment, could \nindicate a potential credit risk.) \nSummary for Supervisor: The bank has seen an increase in defaults in its auto loan portfolio, \nparticularly in the subprime segment, indicating potential credit risk. They have increased \ntheir loan loss provisions accordingly. \nSource Citation: "We have seen an uptick in defaults in our auto loan portfolio, particularly in \nthe subprime segment. We are closely monitoring this situation and have increased our loan \nloss provisions accordingly." \nConfidence Score: 0.95 \n \nTopic Title: Implementation of New IT System \nKeywords: IT system, operational efficiency, technical issues, project delay \nRisk Salience Score: 3 (Technical issues and delays in the implementation of a new IT \nsystem could pose operational risks.) \nSummary for Supervisor: The bank\'s new IT system implementation has been delayed due \nto technical issues, posing potential operational risks and impacting operational efficiency. \nSource Citation: "We are in the process of implementing a new IT system to improve our \noperational efficiency. However, the project has been delayed due to some unforeseen \ntechnical issues." \nConfidence Score: 0.85 \n \nTopic Title: Increase in Deposit Base and Competition \nKeywords: Deposit base, liquidity position, market competition \nRisk Salience Score: 2 (Increased deposit base improves liquidity but increased competition \ncould pose a strategic risk.) \nSummary for Supervisor: The bank\'s deposit base has increased, improving its liquidity \nposition. However, increased competition for deposits in the market could pose a strategic \nrisk. \nSource Citation: "We have seen a signi ...
# {'chunk_id': 'UBS_Topic_Modelling_Results_transcript_4', 'doc_name': 'UBS Topic Modelling Results.pdf', 'doc_id': 'UBS_Topic_Modelling_Results', 'content': '--- GPT-4 Topic Modelling Output --- \nExcerpt for Analysis: \n \n"1. The bank\'s management highlighted that the bank\'s net interest margin (NIM) has been \nunder pressure due to the low-interest-rate environment, impacting the bank\'s profitability. \nThey are considering a shift towards non-interest income sources, such as fee-based \nservices, to offset this impact. \n \n2. There was a discussion on the bank\'s exposure to the commercial real estate (CRE) \nsector, which has been hit hard by the pandemic. The bank\'s management stated that they \nhave increased provisions for potential loan losses in this sector. \n \n3. The bank\'s management also mentioned that they are investing heavily in digital \ntransformation, with a focus on improving customer experience and operational efficiency. \nThey expect this to lead to cost savings in the long run. \n \n4. The bank\'s management discussed their strategy to diversify their loan portfolio to reduce \nconcentration risk. They are looking at expanding into new sectors and geographies. \n \n5. There were concerns raised about the bank\'s reliance on wholesale funding, which has \nbeen volatile due to market uncertainties. The bank\'s management stated that they are \nworking on improving their deposit base to reduce this reliance." \n \nTopic Identification: \n- Impact of low-interest-rate environment on the bank\'s net interest margin (NIM) \n- Bank\'s exposure to the commercial real estate (CRE) sector \n- Bank\'s investment in digital transformation \n- Strategy to diversify the loan portfolio \n- Bank\'s reliance on wholesale funding \n \nDetailed Topic Analysis: \n \nTopic Title: Impact of Low-Interest-Rate Environment on NIM \nKeywords: Net Interest Margin, Low-Interest-Rate, Profitability, Non-Interest Income \nRisk Salience Score: 4 (The low-interest-rate environment is a significant market risk \nimpacting the bank\'s profitability.) \nSummary for Supervisor: The bank\'s NIM is under pressure due to the low-interest-rate \nenvironment, impacting profitability. The bank is considering a shift towards non-interest \nincome sources, indicating a strategic shift in their business model. \nSource Citation: Excerpt 1 \nConfidence Score: 0.9\n\nTopic Title: Exposure to Commercial Real Estate Sector \nKeywords: Commercial Real Estate, Loan Loss Provisions, Credit Risk \nRisk Salience Score: 4 (Increased loan loss provisions indicate a significant credit risk in the \nbank\'s CRE portfolio.) \nSummary for Supervisor: The bank\'s exposure to the pandemic-hit CRE sector and \nincreased loan loss provisions indicate a significant credit risk not evident in headline \nmetrics. \nSource Citation: Excerpt 2 \nConfidence Score: 0.9 \n \nTopic Title: Investment in Digital Transformation \nKeywords: Digital Transformation, Operational Efficiency, Cost Savings, Strategic Risk \nRisk Salience Score: 3 (Investment in digital transformation indicates a strategic shift, but \nalso potential operational risks.) \nSummary for Supervisor: The bank\'s heavy investment in digital transformation, aimed at \nimproving customer experience and operational efficiency, indicates a strategic shift. \nHowever, it could also introduce operational risks related to IT failures and cyber security. \nSource Citation: Excerpt 3 \nConfidence Score: 0.8 \n \nTopic Title: Diversification of Loan Portfolio \nKeywords: Loan Portfolio, Diversification, Concentration Risk, Strategic Risk \nRisk Salience Score: 3 (Diversification strategy indicates a strategic shift and potential \nchanges in credit risk profile.) \nSummary for Supervisor: The bank\'s strategy to diversify its loan portfolio to reduce \nconcentration risk indicates a strategic shift in its business model and potential changes in its \ncredit risk profile. \nSource Citation: Excerpt 4 \nConfidenc ...
# {'chunk_id': 'UBS_Topic_Modelling_Results_transcript_5', 'doc_name': 'UBS Topic Modelling Results.pdf', 'doc_id': 'UBS_Topic_Modelling_Results', 'content': '--- GPT-4 Topic Modelling Output --- \nExcerpt for Analysis:\n\n"Management addressed concerns about the bank\'s exposure to emerging markets, \nparticularly in Asia. They acknowledged that the economic slowdown in China could impact \ntheir loan book, but emphasized that they have robust risk management strategies in place. \nAnalysts also questioned the bank\'s decision to increase investments in fintech, which \nmanagement defended as a strategic move to stay competitive. The bank\'s net interest \nmargin (NIM) was also a topic of discussion, with management noting that it had been \nimpacted by recent interest rate cuts. Finally, the bank\'s increasing reliance on wholesale \nfunding was discussed, with management assuring that they have sufficient liquidity buffers \nin place." \n \nTop 5 Key Topics: \n \n1. Bank\'s exposure to emerging markets, particularly in Asia \n2. Impact of economic slowdown in China on the bank\'s loan book \n3. Bank\'s decision to increase investments in fintech \n4. Impact of interest rate cuts on the bank\'s net interest margin (NIM) \n5. Bank\'s increasing reliance on wholesale funding \n \nDetailed Topic Analysis: \n \nTopic Title: Exposure to Emerging Markets \nKeywords: Emerging markets, Asia, exposure, risk management \nRisk Salience Score: 4 (High risk due to potential volatility and uncertainty in emerging \nmarkets) \nSummary for Supervisor: The bank\'s significant exposure to emerging markets, particularly \nin Asia, could pose a credit risk if these markets experience economic instability. \nManagement asserts robust risk management strategies are in place. \nSource Citation: "Management addressed concerns about the bank\'s exposure to emerging \nmarkets, particularly in Asia." \nConfidence Score: 0.9 \n \nTopic Title: Economic Slowdown in China \nKeywords: China, economic slowdown, loan book, credit risk \nRisk Salience Score: 4 (High risk due to potential impact on loan book quality) \nSummary for Supervisor: The economic slowdown in China could negatively impact the \nbank\'s loan book, indicating a potential credit risk. Management\'s risk mitigation strategies \nshould be scrutinized. \nSource Citation: "They acknowledged that the economic slowdown in China could impact \ntheir loan book." \nConfidence Score: 0.9 \n \nTopic Title: Increased Investment in Fintech \nKeywords: Fintech, investment, strategic risk, competitive landscape \nRisk Salience Score: 3 (Medium risk due to potential strategic and operational risks \nassociated with new technology adoption) \nSummary for Supervisor: The bank\'s decision to increase investments in fintech could \nindicate a strategic shift and potential operational risks. This move should be monitored for \nits impact on the bank\'s business model and risk profile.\n\nSource Citation: "Analysts also questioned the bank\'s decision to increase investments in \nfintech." \nConfidence Score: 0.8 \n \nTopic Title: Impact of Interest Rate Cuts on NIM \nKeywords: Interest rate cuts, net interest margin, market risk \nRisk Salience Score: 3 (Medium risk due to potential impact on profitability) \nSummary for Supervisor: Recent interest rate cuts have impacted the bank\'s net interest \nmargin, indicating a potential market risk. This could affect the bank\'s profitability and should \nbe closely monitored. \nSource Citation: "The bank\'s net interest margin (NIM) was also a topic of discussion." \nConfidence Score: 0.9 \n \nTopic Title: Reliance on Wholesale Funding \nKeywords: Wholesale funding, liquidity risk, liquidity buffers \nRisk Salience Score: 4 (High risk due to potential liquidity concerns) \nSummary for Supervisor: The bank\'s increasing reliance on wholesale funding could pose a \nliquidity risk. Management\'s assurance of sufficient liquidity buffers should be verified. \nSource Citat ...
# {'chunk_id': 'UBS_Topic_Modelling_Results_transcript_6', 'doc_name': 'UBS Topic Modelling Results.pdf', 'doc_id': 'UBS_Topic_Modelling_Results', 'content': '--- GPT-4 Topic Modelling Output --- \nExcerpt for Analysis: \n \n"The bank\'s net interest margin has been under pressure due to the low interest rate \nenvironment. Management is considering a strategic shift towards more fee-based services \nto offset this. There are also concerns about the bank\'s exposure to the commercial real \nestate sector, given the current economic uncertainty. The bank\'s IT infrastructure has been \na topic of discussion, with questions raised about its resilience and ability to support the \nbank\'s operations. Finally, the bank\'s capital adequacy ratio has improved, but analysts are \nworried about the potential impact of future regulatory changes." \n \nTopic Identification: \n \n1. Pressure on Net Interest Margin \n2. Strategic Shift towards Fee-based Services \n3. Exposure to Commercial Real Estate Sector \n4. Resilience of IT Infrastructure \n5. Capital Adequacy Ratio and Regulatory Changes \n \nDetailed Topic Analysis: \n \nTopic Title: Pressure on Net Interest Margin \nKeywords: Net Interest Margin, Low Interest Rate, Revenue Pressure\n\nRisk Salience Score: 3 (The low-interest-rate environment is impacting the bank\'s net \ninterest margin, which could affect profitability.) \nSummary for Supervisor: The bank\'s net interest margin is under pressure due to the \nlow-interest-rate environment, which could impact revenue and profitability. This situation \nrequires monitoring as it could affect the bank\'s financial stability. \nSource Citation: "The bank\'s net interest margin has been under pressure due to the low \ninterest rate environment." \nConfidence Score: 0.9 \n \nTopic Title: Strategic Shift towards Fee-based Services \nKeywords: Strategic Shift, Fee-based Services, Revenue Diversification \nRisk Salience Score: 2 (The bank\'s strategic shift could indicate a change in risk appetite \nand business model.) \nSummary for Supervisor: The bank is considering a strategic shift towards more fee-based \nservices to diversify its revenue streams. This could indicate a change in risk appetite and \nbusiness model, requiring further assessment. \nSource Citation: "Management is considering a strategic shift towards more fee-based \nservices to offset this." \nConfidence Score: 0.8 \n \nTopic Title: Exposure to Commercial Real Estate Sector \nKeywords: Commercial Real Estate, Sector Exposure, Economic Uncertainty \nRisk Salience Score: 4 (The bank\'s exposure to the commercial real estate sector amid \neconomic uncertainty could lead to potential credit risk.) \nSummary for Supervisor: The bank\'s exposure to the commercial real estate sector amid \neconomic uncertainty could lead to potential credit risk. This requires close monitoring and \nassessment of the bank\'s risk management practices. \nSource Citation: "There are also concerns about the bank\'s exposure to the commercial real \nestate sector, given the current economic uncertainty." \nConfidence Score: 0.9 \n \nTopic Title: Resilience of IT Infrastructure \nKeywords: IT Infrastructure, Operational Risk, Resilience \nRisk Salience Score: 4 (Questions about the bank\'s IT infrastructure resilience could indicate \npotential operational risks.) \nSummary for Supervisor: Questions about the resilience of the bank\'s IT infrastructure could \nindicate potential operational risks. This requires further investigation to ensure the bank\'s \noperational continuity and risk management. \nSource Citation: "The bank\'s IT infrastructure has been a topic of discussion, with questions \nraised about its resilience and ability to support the bank\'s operations." \nConfidence Score: 0.8 \n \nTopic Title: Capital Adequacy Ratio and Regulatory Changes \nKeywords: Capital Adequacy Ratio, Regulatory Changes, Compliance Risk \nRisk Salience Score: 3 (Concerns about potential impact of future re ...
# {'chunk_id': 'UBS_Topic_Modelling_Results_transcript_7', 'doc_name': 'UBS Topic Modelling Results.pdf', 'doc_id': 'UBS_Topic_Modelling_Results', 'content': '--- GPT-4 Topic Modelling Output --- \nExcerpt for Analysis: \n \n"1. Our net interest margin (NIM) was down 15 basis points (bps) due to lower interest rates \nglobally, which is impacting our profitability. We are working on strategies to mitigate this, \nincluding diversifying our revenue streams and increasing our focus on non-interest income. \n \n2. We have seen a significant increase in loan defaults, particularly in our commercial real \nestate portfolio. This is due to the economic downturn caused by the pandemic. We are \nclosely monitoring this and have increased our loan loss provisions accordingly. \n \n3. We are investing heavily in digital transformation, including automation and AI, to improve \nour operational efficiency and customer experience. However, this comes with increased IT \nand cybersecurity risks, which we are managing through robust controls and regular testing. \n \n4. We have experienced a high level of deposit outflows, which has put pressure on our \nliquidity. We are managing this by increasing our access to wholesale funding and \nmaintaining a strong liquidity coverage ratio. \n \n5. We have been subject to increased regulatory scrutiny due to allegations of mis-selling. \nWe are taking steps to address this, including improving our sales practices and enhancing \nour customer complaint handling processes." \n \nAnalysis: \n \n- Topic 1: Impact of Lower Interest Rates on Profitability \n  - Keywords: Net Interest Margin, Interest Rates, Profitability \n  - Risk Salience Score: 4 (Lower interest rates are impacting the bank\'s profitability, posing a \nsignificant financial risk.) \n  - Summary for Supervisor: Lower global interest rates have reduced the bank\'s NIM by \n15bps, impacting profitability. The bank is planning to mitigate this by diversifying revenue \nstreams and focusing on non-interest income. \n  - Source Citation: Sentence 1 \n  - Confidence Score: 0.9 \n \n- Topic 2: Increase in Loan Defaults \n  - Keywords: Loan Defaults, Commercial Real Estate, Loan Loss Provisions\n\n- Risk Salience Score: 5 (Increased loan defaults, particularly in the commercial real estate \nportfolio, pose a high credit risk.) \n  - Summary for Supervisor: The bank has seen a significant increase in loan defaults due to \nthe economic downturn, leading to increased loan loss provisions. This indicates a high \ncredit risk, particularly in the commercial real estate portfolio. \n  - Source Citation: Sentence 2 \n  - Confidence Score: 1 \n \n- Topic 3: Investment in Digital Transformation \n  - Keywords: Digital Transformation, Operational Efficiency, IT and Cybersecurity Risks \n  - Risk Salience Score: 3 (Investment in digital transformation brings operational benefits but \nalso increases IT and cybersecurity risks.) \n  - Summary for Supervisor: The bank\'s heavy investment in digital transformation, including \nautomation and AI, aims to improve operational efficiency and customer experience but also \nincreases IT and cybersecurity risks. \n  - Source Citation: Sentence 3 \n  - Confidence Score: 0.8 \n \n- Topic 4: High Level of Deposit Outflows \n  - Keywords: Deposit Outflows, Liquidity, Wholesale Funding \n  - Risk Salience Score: 4 (High deposit outflows are putting pressure on the bank\'s liquidity, \nposing a significant liquidity risk.) \n  - Summary for Supervisor: The bank has experienced high deposit outflows, putting \npressure on liquidity. The bank is managing this by increasing access to wholesale funding \nand maintaining a strong liquidity coverage ratio. \n  - Source Citation: Sentence 4 \n  - Confidence Score: 0.9 \n \n- Topic 5: Increased Regulatory Scrutiny Due to Allegations of Mis-selling \n  - Keywords: Regulatory Scrutiny, Mis-selling, Sales Practices \n  - Risk Salience Score: 5 (Allegations of mis-selling have led t ...
# {'chunk_id': 'UBS_Topic_Modelling_Results_transcript_8', 'doc_name': 'UBS Topic Modelling Results.pdf', 'doc_id': 'UBS_Topic_Modelling_Results', 'content': '--- GPT-4 Topic Modelling Output --- \nExcerpt for Analysis: \n \n"Firstly, we have seen a significant increase in our loan book, particularly in the commercial \nand industrial sector, which has been driven by the current low-interest rate environment. \nHowever, we have also seen a slight uptick in defaults, particularly in the retail sector, which \nwe believe is a result of the ongoing economic uncertainty.\n\nSecondly, we are in the process of implementing a new IT system to improve our operational \nefficiency. This is a major undertaking and we have experienced some initial teething \nproblems, but we are confident that these will be resolved in the near future. \n \nThirdly, we have been exploring opportunities for expansion into emerging markets, \nparticularly in Asia. We believe that this represents a significant growth opportunity for us, \nbut we are aware of the potential risks and are taking a cautious approach. \n \nFourthly, we have been the subject of some negative media coverage recently, which has \nhad an impact on our reputation. We are taking steps to address this and are confident that \nwe can rebuild trust with our stakeholders. \n \nFinally, we have been reviewing our risk models in light of recent regulatory changes. We \nbelieve that our models are robust, but we are taking steps to ensure that they are fully \ncompliant with the new regulations." \n \nTopic Identification: \n \n1. Increase in loan book and defaults \n2. Implementation of a new IT system \n3. Expansion into emerging markets \n4. Negative media coverage and reputational impact \n5. Review of risk models due to regulatory changes \n \nDetailed Topic Analysis: \n \nTopic Title: Increase in Loan Book and Defaults \nKeywords: Loan book, defaults, commercial and industrial sector, retail sector, economic \nuncertainty \nRisk Salience Score: 4 (The increase in defaults, particularly in the retail sector, could \npotentially lead to significant credit risk.) \nSummary for Supervisor: The bank has seen a significant increase in its loan book and a \nslight uptick in defaults, particularly in the retail sector. This could potentially lead to \nsignificant credit risk, especially in the context of ongoing economic uncertainty. \nSource Citation: "Firstly, we have seen a significant increase in our loan book, particularly in \nthe commercial and industrial sector, which has been driven by the current low-interest rate \nenvironment. However, we have also seen a slight uptick in defaults, particularly in the retail \nsector, which we believe is a result of the ongoing economic uncertainty." \nConfidence Score: 0.9 \n \nTopic Title: Implementation of New IT System \nKeywords: IT system, operational efficiency, teething problems \nRisk Salience Score: 3 (The implementation of a new IT system could potentially lead to \noperational risks if not properly managed.) \nSummary for Supervisor: The bank is implementing a new IT system to improve operational \nefficiency. Although they have experienced some initial problems, they are confident these \nwill be resolved. This could potentially lead to operational risks if not properly managed.\n\nSource Citation: "Secondly, we are in the process of implementing a new IT system to \nimprove our operational efficiency. This is a major undertaking and we have experienced \nsome initial teething problems, but we are confident that these will be resolved in the near \nfuture." \nConfidence Score: 0.8 \n \nTopic Title: Expansion into Emerging Markets \nKeywords: Expansion, emerging markets, Asia, growth opportunity, potential risks \nRisk Salience Score: 4 (Expansion into emerging markets could potentially lead to strategic \nand market risks.) \nSummary for Supervisor: The bank is exploring opportunities for expansion into emerging \nmarkets, particularly i ...
# {'chunk_id': 'UBS_Topic_Modelling_Results_transcript_9', 'doc_name': 'UBS Topic Modelling Results.pdf', 'doc_id': 'UBS_Topic_Modelling_Results', 'content': '--- GPT-4 Topic Modelling Output --- \nExcerpt for Analysis:\n\n"1. Our loan book quality remains strong, but we are closely monitoring our exposure to the \nretail sector, which has been under significant pressure due to the ongoing pandemic.  \n \n2. We are also seeing some currency fluctuations that are impacting our international \noperations, but we believe our hedging strategies are effectively managing this risk. \n \n3. We have made significant investments in our IT infrastructure to improve our cyber \nsecurity and are confident in our ability to manage this risk. \n \n4. We are also exploring opportunities to expand our operations in emerging markets, which \nwe believe offer significant growth potential. \n \n5. We have a robust risk management framework in place and are committed to maintaining \nour reputation as a responsible lender." \n \nKey Topics: \n \n1. Loan book quality and exposure to the retail sector \n2. Currency fluctuations and hedging strategies \n3. Investments in IT infrastructure and cyber security \n4. Expansion into emerging markets \n5. Risk management framework and reputation maintenance \n \nDetailed Topic Analysis: \n \nTopic Title: Loan Book Quality and Retail Sector Exposure \nKeywords: Loan book quality, retail sector, exposure, pandemic, credit risk \nRisk Salience Score: 4 (High risk due to potential defaults and deteriorating loan book quality \nin the retail sector.) \nSummary for Supervisor: The bank\'s exposure to the struggling retail sector amid the \npandemic poses a significant credit risk, despite the reported strong loan book quality. This \nrequires close monitoring to prevent potential defaults. \nSource Citation: "Our loan book quality remains strong, but we are closely monitoring our \nexposure to the retail sector, which has been under significant pressure due to the ongoing \npandemic." \nConfidence Score: 0.9 \n \nTopic Title: Currency Fluctuations and Hedging Strategies \nKeywords: Currency fluctuations, international operations, hedging strategies, market risk \nRisk Salience Score: 3 (Moderate risk due to potential losses from currency fluctuations, \nmitigated by hedging strategies.) \nSummary for Supervisor: The bank\'s international operations are exposed to currency \nfluctuations, posing a market risk. However, the bank\'s hedging strategies are reportedly \nmanaging this risk effectively. \nSource Citation: "We are also seeing some currency fluctuations that are impacting our \ninternational operations, but we believe our hedging strategies are effectively managing this \nrisk." \nConfidence Score: 0.8\n\nTopic Title: IT Infrastructure Investments and Cyber Security \nKeywords: IT infrastructure, investments, cyber security, operational risk \nRisk Salience Score: 2 (Low risk due to significant investments in IT infrastructure and \nconfidence in managing cyber security risk.) \nSummary for Supervisor: The bank has made significant investments in IT infrastructure to \nbolster cyber security, which should mitigate operational risks related to IT failures and cyber \nthreats. \nSource Citation: "We have made significant investments in our IT infrastructure to improve \nour cyber security and are confident in our ability to manage this risk." \nConfidence Score: 0.9 \n \nTopic Title: Expansion into Emerging Markets \nKeywords: Expansion, emerging markets, growth potential, strategic risk \nRisk Salience Score: 3 (Moderate risk due to potential challenges and uncertainties in \nemerging markets.) \nSummary for Supervisor: The bank\'s strategic shift towards expanding in emerging markets \ncould introduce new risks due to market volatility and regulatory uncertainties, despite the \npotential for growth. \nSource Citation: "We are also exploring opportunities to expand our operations in emerging \nmarkets, whi ...
# {'chunk_id': 'UBS_Topic_Modelling_Results_consolidated', 'doc_name': 'UBS Topic Modelling Results.pdf', 'doc_id': 'UBS_Topic_Modelling_Results', 'content': "All Topics \n1.\u200b\nStrategic exit from certain emerging markets \n2.\u200b\nDe-risking of the loan book, particularly in the commercial real estate sector \n3.\u200b\nInvestment in IT infrastructure and cyber security defenses \n4.\u200b\nMaintenance of a strong liquidity position and diversification of funding sources \n5.\u200b\nImplementation of a program to improve culture and conduct \n6.\u200b\nPressure on Net Interest Margin (NIM) due to low interest rate environment \n7.\u200b\nIncreased competition in core markets \n8.\u200b\nConcerns about IT systems and related failures \n9.\u200b\nCapital adequacy ratio (CAR) and potential impact of business model changes \n10.\u200b\nExposure to the commercial real estate sector \n11.\u200b\nPressure on Net Interest Margin (NIM) \n12.\u200b\nIncrease in Auto Loan Defaults \n13.\u200b\nImplementation of New IT System \n14.\u200b\nIncrease in Deposit Base and Competition \n15.\u200b\nRegulatory Scrutiny Over Sales Practices \n16.\u200b\nImpact of low-interest-rate environment on the bank's net interest margin (NIM) \n17.\u200b\nBank's exposure to the commercial real estate (CRE) sector \n18.\u200b\nBank's investment in digital transformation \n19.\u200b\nStrategy to diversify the loan portfolio \n20.\u200b\nBank's reliance on wholesale funding \n21.\u200b\nBank's exposure to emerging markets, particularly in Asia \n22.\u200b\nImpact of economic slowdown in China on the bank's loan book \n23.\u200b\nBank's decision to increase investments in fintech \n24.\u200b\nImpact of interest rate cuts on the bank's net interest margin (NIM) \n25.\u200b\nBank's increasing reliance on wholesale funding \n26.\u200b\nPressure on Net Interest Margin \n27.\u200b\nStrategic Shift towards Fee-based Services \n28.\u200b\nExposure to Commercial Real Estate Sector \n29.\u200b\nResilience of IT Infrastructure \n30.\u200b\nCapital Adequacy Ratio and Regulatory Changes \n31.\u200b\nIncrease in loan book and defaults \n32.\u200b\nImplementation of a new IT system \n33.\u200b\nExpansion into emerging markets \n34.\u200b\nNegative media coverage and reputational impact \n35.\u200b\nReview of risk models due to regulatory changes \n36.\u200b\nLoan book quality and exposure to the retail sector \n37.\u200b\nCurrency fluctuations and hedging strategies \n38.\u200b\nInvestments in IT infrastructure and cyber security \n39.\u200b\nExpansion into emerging markets \n40.\u200b\nRisk management framework and reputation maintenance\n\nReview: \nCredit Risk: Medium \n Operational Risk: Medium  \nLiquidity Risk: Medium  \nReputational & Conduct Risk: Medium \n \nTop 5 Topics: \n \n1. Pressure on Net Interest Margin (NIM) \nComprised of topics: 6, 11, 16, 24, 26 \n \n2. Concerns about IT Systems and Cyber Security \nComprised of topics: 3, 8, 13, 18, 29, 32, 38 \n \n3. Exposure to the Commercial Real Estate (CRE) Sector \nComprised of topics: 2, 10, 17, 28 \n \n4. Capital Adequacy and Regulatory Changes \nComprised of topics: 9, 30, 35 \n \n5. Strategic Exit/Exposure to Emerging Markets \nComprised of topics: 1, 21, 22, 33, 39", 'section_type': 'consolidated', 'char_count': 2786, 'claude_analysis': {'risk_categories': ['credit risk', 'operational risk', 'liquidity risk', 'reputational risk'], 'topics': ['Net Interest Margin (NIM)', 'IT Systems and Cyber Security', 'Commercial Real Estate Exposure', 'Capital Adequacy', 'Emerging Markets Strategy', 'Regulatory Compliance', 'Digital Transformation', 'Funding Sources'], 'risk_level': 'medium', 'main_concerns': ['Declining net interest margins due to low interest rates', 'IT infrastructure and cybersecurity vulnerabilities', 'Commercial real estate sector exposure', 'Regulatory compliance and capital adequacy', 'Emerging markets risk exposure'], 'metrics': ['Net Interest Margin (NIM): pressure/declining', 'Capital Adequa ...
# ...
# {'chunk_id': 'Silicon_Vallet_Topic_Modelling_Results_transcript_8', 'doc_name': 'Silicon Vallet Topic Modelling Results.pdf', 'doc_id': 'Silicon_Vallet_Topic_Modelling_Results', 'content': '--- GPT-4 Topic Modelling Output --- \nExcerpt for Analysis: \n \n"Analyst 1: Can you provide some color on your loan book quality, especially in the \ncommercial real estate sector? We\'ve seen some defaults in that space recently. \n \nCEO: We have been monitoring our commercial real estate portfolio closely. We\'ve seen a \nslight uptick in defaults, but nothing alarming. We believe our underwriting standards and \nrisk management practices have held up well. \n \nAnalyst 2: What about your exposure to the energy sector? There\'s a lot of volatility there. \n \nCEO: Yes, we have some exposure to the energy sector, but it\'s manageable. We\'ve been \nproactive in managing our risk there, and we\'ve taken steps to reduce our exposure. \n \nAnalyst 3: I\'m concerned about your IT infrastructure. There have been reports of system \nfailures recently. Can you comment on that? \n \nCIO: We\'ve had a few isolated incidents, but we\'ve addressed them promptly. We\'re \ninvesting heavily in our IT infrastructure to prevent future issues. \n \nAnalyst 4: What\'s your strategy for dealing with potential interest rate changes? \n \nCFO: We\'re actively managing our interest rate risk. We have a diversified portfolio and \nwe\'re prepared for potential changes in the interest rate environment. \n \nAnalyst 5: How are you managing your liquidity risk, given the current market conditions? \n \nCFO: We have a robust liquidity management framework in place. We\'re confident in our \nability to meet our financial obligations." \n \n--- \n \nTopic Identification: \n \n1. Quality of the loan book and exposure to the commercial real estate sector \n2. Exposure to the energy sector \n3. Concerns about IT infrastructure and system failures \n4. Strategy for dealing with potential interest rate changes \n5. Liquidity risk management in current market conditions\n\n--- \n \nDetailed Topic Analysis: \n \nTopic Title: Quality of Loan Book and Exposure to Commercial Real Estate Sector \nKeywords: Loan book quality, commercial real estate, defaults, underwriting standards, risk \nmanagement \nRisk Salience Score: 4 (The slight uptick in defaults in the commercial real estate sector \nindicates a potential increase in credit risk.) \nSummary for Supervisor: The bank\'s commercial real estate portfolio has seen a slight \nincrease in defaults, suggesting potential credit risk. The bank\'s underwriting standards and \nrisk management practices should be scrutinized to ensure they are robust enough to \nmitigate this risk. \nSource Citation: "We have been monitoring our commercial real estate portfolio closely. \nWe\'ve seen a slight uptick in defaults, but nothing alarming. We believe our underwriting \nstandards and risk management practices have held up well." \nConfidence Score: 0.9 \n \nTopic Title: Exposure to the Energy Sector \nKeywords: Energy sector, exposure, volatility, risk management \nRisk Salience Score: 3 (The bank\'s exposure to the volatile energy sector could increase \nmarket risk.) \nSummary for Supervisor: The bank has exposure to the volatile energy sector, which could \nincrease market risk. The bank\'s risk management practices in this area should be reviewed \nto ensure they are effective. \nSource Citation: "Yes, we have some exposure to the energy sector, but it\'s manageable. \nWe\'ve been proactive in managing our risk there, and we\'ve taken steps to reduce our \nexposure." \nConfidence Score: 0.8 \n \nTopic Title: Concerns about IT Infrastructure and System Failures \nKeywords: IT infrastructure, system failures, operational risk, investment \nRisk Salience Score: 4 (Recent system failures highlight potential operational risk.) \nSummary for Supervisor: Recent system failures at the bank indicate potential operational \nrisk. The bank\'s ...
# {'chunk_id': 'Silicon_Vallet_Topic_Modelling_Results_transcript_9', 'doc_name': 'Silicon Vallet Topic Modelling Results.pdf', 'doc_id': 'Silicon_Vallet_Topic_Modelling_Results', 'content': '--- GPT-4 Topic Modelling Output --- \nExcerpt for Analysis: \n \n"Firstly, we\'ve seen a significant increase in our loan book, particularly in the retail sector. \nHowever, we\'ve also seen a rise in defaults, particularly in the auto loan sector. Secondly, \nwe\'re seeing a shift in our business model towards more digital banking, which has been \naccelerated by the pandemic. Thirdly, we\'re seeing a significant increase in cyber security \nthreats, which we\'re addressing through increased investment in our IT infrastructure. \nFourthly, we\'re seeing increased scrutiny from regulators, particularly in relation to our risk \nmanagement practices. Finally, we\'re seeing a shift in consumer behavior, with more \ncustomers moving to online banking and fewer visiting our branches." \n \nTopic Identification: \n \n1. Increase in loan book and rise in defaults \n2. Shift towards digital banking \n3. Increase in cyber security threats \n4. Increased regulatory scrutiny \n5. Shift in consumer behavior towards online banking \n \nDetailed Topic Analysis: \n \nTopic Title: Rising Defaults in Loan Book \nKeywords: Defaults, Loan Book, Retail Sector, Auto Loans, Credit Risk \nRisk Salience Score: 4 (High risk due to potential credit losses and impact on capital \nadequacy.) \nSummary for Supervisor: The bank\'s significant increase in the loan book, especially in the \nretail sector, coupled with rising defaults in auto loans, signals potential credit risk. This could \nimpact capital adequacy and profitability.\n\nSource Citation: "Firstly, we\'ve seen a significant increase in our loan book, particularly in the \nretail sector. However, we\'ve also seen a rise in defaults, particularly in the auto loan sector." \nConfidence Score: 0.9 \n \nTopic Title: Shift Towards Digital Banking \nKeywords: Digital Banking, Business Model, Strategic Shift, Operational Risk \nRisk Salience Score: 3 (Medium risk due to potential operational and cyber security risks \nassociated with digital banking.) \nSummary for Supervisor: The bank\'s shift towards digital banking, accelerated by the \npandemic, indicates a strategic shift that could increase operational and cyber security risks. \nSource Citation: "Secondly, we\'re seeing a shift in our business model towards more digital \nbanking, which has been accelerated by the pandemic." \nConfidence Score: 0.8 \n \nTopic Title: Increase in Cyber Security Threats \nKeywords: Cyber Security, IT Infrastructure, Operational Risk \nRisk Salience Score: 5 (High risk due to potential financial and reputational damage from \ncyber attacks.) \nSummary for Supervisor: The bank\'s reported increase in cyber security threats, despite \nincreased IT investment, signals a high operational risk that could lead to financial and \nreputational damage. \nSource Citation: "Thirdly, we\'re seeing a significant increase in cyber security threats, which \nwe\'re addressing through increased investment in our IT infrastructure." \nConfidence Score: 0.9 \n \nTopic Title: Increased Regulatory Scrutiny \nKeywords: Regulatory Scrutiny, Risk Management, Reputational Risk \nRisk Salience Score: 3 (Medium risk due to potential reputational damage and regulatory \nfines.) \nSummary for Supervisor: The bank\'s increased regulatory scrutiny, particularly on risk \nmanagement practices, could lead to reputational damage and regulatory fines, indicating a \npotential reputational risk. \nSource Citation: "Fourthly, we\'re seeing increased scrutiny from regulators, particularly in \nrelation to our risk management practices." \nConfidence Score: 0.8 \n \nTopic Title: Shift in Consumer Behavior \nKeywords: Consumer Behavior, Online Banking, Operational Risk \nRisk Salience Score: 2 (Low risk but indicates a strategic shift towards digital banking.) \nSum ...
# {'chunk_id': 'Silicon_Vallet_Topic_Modelling_Results_consolidated', 'doc_name': 'Silicon Vallet Topic Modelling Results.pdf', 'doc_id': 'Silicon_Vallet_Topic_Modelling_Results', 'content': "All Topics \n1.      Exposure to the commercial real estate sector \n2.      Expansion into the Asian market \n3.      IT infrastructure and operational risk \n4.      Reliance on wholesale funding and liquidity risk \n5.      Bank's culture and conduct risk \n6.      Increase in loan loss provisions \n7.      Liquidity risk management \n8.      IT infrastructure and operational risk \n9.      Climate change risk management \n10.  Strategy in response to fintech competition \n11.  Volatility in the trading book \n12.  Changes to the business model in the retail banking division \n13.  Increase in defaults in the loan book \n14.  Cyber security issues resulting in IT failures \n15.  Negative media scrutiny impacting reputation \n16.  Net Interest Margin and Loan Book Quality \n17.  Digital Transformation and Cyber Security \n18.  Liquidity Risk Management \n19.  Growth Strategy in Emerging Markets \n20.  Capital Position and Dividend Policy \n21.  Increase in loan defaults, particularly in the retail sector. \n22.  Exposure to emerging markets and economic instability. \n23.  Concerns about the bank's IT infrastructure and potential for cyber attacks. \n24.  Strategic shift towards digital banking and impact on traditional banking operations. \n25.  Bank's liquidity position and reliance on wholesale funding. \n26.  Increase in loan loss provisions and defaults due to COVID-19. \n27.  Investment in IT infrastructure and challenges faced. \n28.  Exploration of M&A activity for portfolio diversification. \n29.  Shift in customer base towards digital banking. \n30.  Negative media coverage related to allegations of mis-selling of financial products. \n31.  Decline in Net Interest Income \n32.  Increased Exposure to Commercial Real Estate Sector \n33.  IT System Upgrades \n34.  Expansion in Emerging Markets \n35.  Regulatory Fines \n36.  Quality of the loan book and exposure to the commercial real estate sector \n37.  Exposure to the energy sector \n38.  Concerns about IT infrastructure and system failures \n39.  Strategy for dealing with potential interest rate changes \n40.  Liquidity risk management in current market conditions \n41.  Increase in loan book and rise in defaults \n42.  Shift towards digital banking \n43.  Increase in cyber security threats \n44.  Increased regulatory scrutiny \n45.  Shift in consumer behavior towards online banking\n\nReview: \nCredit Risk: High \nOperational Risk: High \nLiquidity Risk: High \nReputational & Conduct Risk: Medium-High \n \n1. IT infrastructure and operational risk \n●\u200b Comprised of: 3, 8, 14, 17, 23, 27, 33, 38, 43 \n2. Liquidity risk management \n●\u200b Comprised of: 4, 7, 18, 25, 40 \n3. Increase in loan loss provisions and defaults in the loan book \n●\u200b Comprised of: 6, 13, 16, 21, 26, 31, 36, 41 \n4. Exposure to the commercial real estate sector \n●\u200b Comprised of: 1, 32, 36 \n5. Digital Transformation and Cyber Security \n●\u200b Comprised of: 10, 17, 24, 29, 42, 45", 'section_type': 'consolidated', 'char_count': 2898, 'claude_analysis': {'risk_categories': ['Credit Risk', 'Operational Risk', 'Liquidity Risk', 'Reputational Risk', 'Conduct Risk'], 'topics': ['IT Infrastructure and Cybersecurity', 'Digital Transformation', 'Commercial Real Estate Exposure', 'Loan Portfolio Quality', 'Liquidity Management', 'Emerging Markets', 'Customer Behavior Shifts'], 'risk_level': {'Credit Risk': 'High', 'Operational Risk': 'High', 'Liquidity Risk': 'High', 'Reputational & Conduct Risk': 'Medium-High'}, 'main_concerns': ['IT infrastructure vulnerabilities and system failures', 'Increasing loan defaults and provisions', 'Heavy reliance on wholesale funding', 'Commercial real estate sector exposure', 'Cybersecurity threats', 'Digital transformation challenges'], 'metrics': ['Net Interest Ma ...

# %%
# Add Topic Modelled Docs to the vectorstore
topic_docs_for_vectorstore = []

for chunk in topic_chunks:
        doc = Document(
            page_content=chunk['content'],
            metadata={
                'source': chunk.get('doc_name', ''),
                'chunk_id': chunk.get('chunk_id', ''),
                'section_type': chunk.get('section_type', '')
            }
        )
        topic_docs_for_vectorstore.append(doc)

# Add to existing vectorstore
vectorstore2.add_documents(topic_docs_for_vectorstore)
# Out:
# ['d59c36a4-7b6e-4723-b5b8-4f328fdedaaf',
#  '53991be0-ecec-46a7-b037-234d946c0b16',
#  '79fb3c13-0246-4b77-8599-1942f43b051a',
#  '94034b26-d06b-4dc5-a8c8-858e350b09da',
#  '2fa73363-d253-4f11-966c-033f95e714d1',
#  '92033866-b2c1-4edc-ab39-5f246694e753',
#  '3e105037-9aca-4da8-bfea-7aa29c5101c5',
#  '6bc4f909-d661-4a9b-9d62-b03a104ccc5c',
#  '6d821118-66a7-4f27-994a-6474f8962914',
#  '79c2f788-2eef-40a8-b9ac-40b09063ef07',
#  'b7098b0e-4b78-4820-80c5-84d0a2cae94a',
#  '043b9594-302d-4814-bfe8-1c41f03595cf',
#  'fb7ea491-96c1-4539-a658-d1a0d7ac279b',
#  '227ebd83-ab85-4ddf-82af-a6a694f0519f',
#  '55c40c97-2620-49ae-8f57-8cf68adac836',
#  'f13879d9-1db1-48e7-99d8-c91bc4adeeee',
#  'c2749407-7c9b-4bc8-9240-952d03822505',
#  '89126250-fa0c-4f9d-acc9-7340c254548f',
#  'e8bdca50-d762-495c-ac1c-a449145f4646',
#  'cf4d1b60-cacf-4723-9736-74a34a06449f',
#  'da337108-e2da-463d-ac74-28671e78af95',
#  'ae9919de-c39d-4e85-9106-3f53b1ddfb7b',
#  '7516581c-1d2f-4b17-925b-08d3e593c7f3',
#  '14c2b012-01f4-41e6-823e-f6b263654dc4',
#  '5a8bbb3c-ce26-4a06-bc19-8e464aa96074',
#  'caf0c5c2-c7fb-461b-bcec-0195c2232488',
#  '33a94160-918d-4993-86b2-7d3cf45a794d',
#  '339f5bd9-de5f-4d6c-bfe1-3416020bed74',
#  '908f1869-93ee-415a-8e3a-83ae330d4f34',
#  'ad1678e7-ac42-4d6f-aa64-272d9ad3d096',
#  'c969391c-5b5b-4ba8-9508-a9f200f5391f',
#  '0a6f446e-fcad-4dfe-9abb-8141af777043',
#  'cbb40f1e-c3b9-482a-ac45-1aed71f7f481',
#  'a3c06b6b-4f0d-4cd2-867d-9ecb47c80bc0',
#  '648b7c07-dc8b-4cfc-9df9-1e937501e0b1',
#  'f646dde4-4038-49e8-a114-bf7ed9f79004',
#  '9a8a0ac4-42cb-4842-a692-6541af910f86',
#  '529c4dc4-5d74-4409-90c1-5403c9f9210b',
#  '121278ca-bcf4-4192-bf5d-bd906f7dd727',
#  'eeff90b7-5eba-4e96-92d2-8a4bb663e8f3',
#  '4864cb53-28fd-4631-a6f0-9b74799a669c',
#  '77b42eb9-6c05-4766-b689-8165b5031d97',
#  '0c596dd9-e37d-496f-abc7-45ab06c1305f',
#  '62e826b5-6536-445a-930d-a7eafd061ec7']

# %% [markdown]
# ### ChatBot

# %%
# Setup some short questions for use within the chatbot
get_questions_for_chatbot = """
You are a financial risk specialist working with large banks such as JP Morgan and Citi. Your job is to come up with questions about the financial risk of the bank and any things that could concern central banks or regulators such as the Bank of England.
You will provide five short questions to the bank in the form of a list as shown below:
["How has the liquidity of the bank been assessed for the coming year?", "What is the outlook for cash generation?", ...]

Requirements:
- Your output must be a valid list, with each question contained in quotes with no other quotes within the question.
- Ask 1 basic questions about the Basel Principles
- Your output must be no longer than 20 words per question.
- The questions should consider specific financial risk of the banks in question as well as any changes in the regulatory environment.
"""

# %%
# Ensure questions are in a format suitable for the Chatbot
questions_for_interface = ast.literal_eval(get_responses(get_questions_for_chatbot, "claude").content)
# Out:
# Question:
# You are a financial risk specialist working with large banks such as JP Morgan and Citi. Your job is to come up with questions about the financial risk of the bank and any things that could concern central banks or regulators such as the Bank of England.
# You will provide five short questions to the bank in the form of a list as shown below:
# ["How has the liquidity of the bank been assessed for the coming year?", "What is the outlook for cash generation?", ...]
#
# Requirements:
# - Your output must be a valid list, with each question contained in quotes with no other quotes within the question.
# - Ask 1 basic questions about the Basel Principles
# - Your output must be no longer than 20 words per question.
# - The questions should consider specific financial risk of the banks in question as well as any changes in the regulatory environment.
#
#
# Claude's Response:
# [
# "How does the bank plan to meet Basel III capital requirements over the next 12 months?",
# "What impact could rising interest rates have on your non-performing loan ratios?",
# "How exposed is your trading book to emerging market volatility?",
# "What contingency measures are in place for potential cybersecurity breaches affecting payment systems?",
# "How would a significant downturn in commercial real estate affect your loan portfolio?"
# ]

# %%
# Enhanced RAG Chatbot with Banking Risk Questions

class BankingRiskChatbot:
    def __init__(self, qa_chain, vectorstore, pre_generated_questions):
        self.qa_chain = qa_chain
        self.vectorstore = vectorstore
        self.pre_generated_questions = pre_generated_questions
        self.conversation_history = []

    def get_response(self, query, chat_history):
        """Process user query and return response with sources"""
        try:
            # Use the QA chain to get response
            result = self.qa_chain.invoke({"query": query})

            # Extract answer and sources
            answer = result.get("result", "I'm sorry, I couldn't find an answer to your question.")
            source_docs = result.get("source_documents", [])

            # Format sources for display
            sources_text = self.format_sources(source_docs)

            # Combine answer with sources
            full_response = f"{answer}\n\n**Sources:**\n{sources_text}"

            # Update chat history
            chat_history.append([query, full_response])

            return chat_history, ""

        except Exception as e:
            error_response = f"Sorry, I encountered an error: {str(e)}"
            chat_history.append([query, error_response])
            return chat_history, ""

    def format_sources(self, source_docs, max_sources=3):
        """Format source documents for display"""
        if not source_docs:
            return "No sources found."

        sources = []
        for i, doc in enumerate(source_docs[:max_sources]):
            source_name = doc.metadata.get('source', 'Unknown source')
            chunk_type = doc.metadata.get('chunk_type', '')
            section_type = doc.metadata.get('section_type', '')

            # Clean up source name
            if source_name.startswith('/tmp/'):
                source_name = source_name.replace('/tmp/', '')

            source_info = f"**{i+1}. {source_name}**"
            if chunk_type:
                source_info += f" ({chunk_type})"
            elif section_type:
                source_info += f" ({section_type})"

            # Add snippet of content
            content_snippet = doc.page_content[:200] + "..." if len(doc.page_content) > 200 else doc.page_content
            source_info += f"\n*{content_snippet}*"

            sources.append(source_info)

        return "\n\n".join(sources)

# Initialize the chatbot
chatbot = BankingRiskChatbot(qa_chain, vectorstore2, questions_for_interface)

def chat_response(message, history):
    """Gradio chat function"""
    return chatbot.get_response(message, history)

def use_suggested_question(question, history):
    """Function to handle suggested question clicks"""
    return chatbot.get_response(question, history)

# Create Gradio interface
with gr.Blocks(
    title="Banking Risk Analysis Chatbot",
    theme=gr.themes.Soft(),
    css="""
    .suggested-questions {
        background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
        border-radius: 10px;
        padding: 15px;
        margin: 10px 0;
    }
    .question-btn {
        margin: 3px;
        background: rgba(255,255,255,0.2);
        border: 1px solid rgba(255,255,255,0.3);
        color: black;
        border-radius: 8px;
        padding: 8px 12px;
        transition: all 0.3s ease;
    }
    .question-btn:hover {
        background: rgba(255,255,255,0.3);
        transform: translateY(-2px);
    }
    """
) as demo:

    gr.Markdown(
        """
        # 🏦 Team Stompa - Banking Risk Analysis Chatbot

        Ask questions about banking regulations, risk management, or use the suggested questions below.
        """
    )

    # Message input
    msg = gr.Textbox(
        label="Ask a question about banking risk...",
        placeholder="e.g., What is Principle 25 about operational risk?",
        lines=2,
        max_lines=5
    )

    # Chat interface
    chatbot_interface = gr.Chatbot(
        label="Banking Risk Assistant",
        height=400,
        show_label=True,
        show_copy_button=True,
        bubble_full_width=False
    )

    # Suggested questions section
    with gr.Group(elem_classes="suggested-questions"):
        gr.Markdown("### 💡 Suggested Questions")
        gr.Markdown("Click any question below to get started:")

        # Create buttons for each pre-generated question
        question_buttons = []
        for i, question in enumerate(questions_for_interface):
            btn = gr.Button(
                question,
                elem_classes="question-btn",
                size="sm"
            )
            question_buttons.append(btn)

    # Control buttons
    with gr.Row():
        clear_btn = gr.Button("🗑️ Clear Chat", variant="secondary")
        submit_btn = gr.Button("📤 Send", variant="primary")

    # Event handlers
    def respond(message, chat_history):
        if message.strip():
            return chatbot.get_response(message, chat_history)
        return chat_history, ""

    def clear_chat():
        chatbot.conversation_history = []
        return [], ""

    # Wire up the interface
    msg.submit(respond, [msg, chatbot_interface], [chatbot_interface, msg])
    submit_btn.click(respond, [msg, chatbot_interface], [chatbot_interface, msg])
    clear_btn.click(clear_chat, [], [chatbot_interface, msg])

    # Wire up suggested question buttons
    for btn in question_buttons:
        btn.click(
            lambda q=btn.value: use_suggested_question(q, []),
            [],
            [chatbot_interface, msg]
        )


    # Footer
    gr.Markdown(
        """
        ---
        **Data Sources:** Basel Principles, Banking Transcripts, Topic Modeling Results
        **Powered by:** Claude 3.5 Sonnet, FAISS Vector Search, LangChain RAG
        """
    )
# Out:
# /tmp/ipython-input-29-3579405824.py:120: UserWarning: You have not specified a value for the `type` parameter. Defaulting to the 'tuples' format for chatbot messages, but this is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style dictionaries with 'role' and 'content' keys.
#   chatbot_interface = gr.Chatbot(
# /tmp/ipython-input-29-3579405824.py:120: DeprecationWarning: The 'bubble_full_width' parameter is deprecated and will be removed in a future version. This parameter no longer has any effect.
#   chatbot_interface = gr.Chatbot(

# %%
# Launch with public sharing for Colab
demo.launch(
    share=True,  # Creates public URL for sharing
    debug=True,
    server_name="0.0.0.0",
    server_port=7860,
    show_error=True
)
# Out:
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# * Running on public URL: https://7726f95db0d052b869.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://7726f95db0d052b869.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
